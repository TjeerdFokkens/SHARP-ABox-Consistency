# %%
import pyactr as actr

# %%
aBoxCon = actr.ACTRModel(
    automatic_visual_search=False,
    motor_prepared=True,
    subsymbolic=True,
    utility_noise=0.2,
    partial_matching=False,
    utility_learning=True,
    production_compilation=True,
    activation_trace=True,
    retrieval_threshold=0,
    decay=0
)

aBoxCon.goals = {}
aBoxCon.set_goal("g")
aBoxCon.set_goal("imaginal")
aBoxCon.set_goal("imaginal_action")
# Out:
# set()

# %%
actr.chunktype("goal", "state")
actr.chunktype("proposition", "thing, form, element, mainconnective, relation, subformula1, inferred1, subformula2, inferred2, derived")
actr.chunktype("checklist", "thing, form, element, mainconnective, relation, subformula1, subformula2, form2, form3, form4, form5, form6, form7, form8")
actr.chunktype("storelist", "thing, form, element, mainconnective, relation, subformula1, subformula2, derived, inferred1, inferred2, form2, form3, form4, form5, form6, form7, form8, form9, form10, form11, form12, form13, form14, form15")


dm = aBoxCon.decmem
goal = aBoxCon.goals["g"]
imaginal = aBoxCon.goals["imaginal"]
imaginal_action = aBoxCon.goals["imaginal_action"]
retrieval = aBoxCon.retrieval
production = aBoxCon.productions

aBoxCon.goals["g"].add(actr.makechunk(typename="goal", state="start"))
aBoxCon.goals["imaginal"].add(actr.makechunk(typename="checklist", thing="checklist"))

# %%
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="a:A&/Es.F", element="a", mainconnective="conjunction", subformula1="a:A", subformula2="a:/Es.F", derived="yes", inferred1="no", inferred2="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="a:/As.(nF%nB)", element="a", mainconnective="universal", relation="s", subformula1="b:nF%nB", derived="yes"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="b:B", element="b", mainconnective="concept", subformula1="B", derived="yes"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="(a,b):s", mainconnective="relation", relation="s", subformula1="a", subformula2="b", derived="yes"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="(a,c):r", mainconnective="relation", relation="r", subformula1="a", subformula2="c", derived="yes"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="c:C&/Es.D", element="c", mainconnective="conjunction", subformula1="c:C", subformula2="c:/Es.D", derived="yes", inferred1="no", inferred2="no"))

dm.add(actr.makechunk(typename="proposition", thing="proposition", form="a:A", element="a", mainconnective="concept", subformula1="A", derived="no"))
#dm.add(actr.makechunk(typename="proposition", thing="proposition", form="x:F", element="x", mainconnective="concept", subformula1="F", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="b:nF%nB", element="b", mainconnective="disjunction", subformula1="b:nF", subformula2="b:nB", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="b:nF", element="b", mainconnective="negation", subformula1="F", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="a:/Es.F", element="a", mainconnective="existential", relation="s", subformula1="x:F", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="(a,x):s", mainconnective="relation", relation="s", subformula1="a", subformula2="x", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="x:nF%nB", element="x", mainconnective="disjunction", subformula1="x:nF", subformula2="x:nB", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="x:nB", element="x", mainconnective="negation", subformula1="B", derived="no"))
#dm.add(actr.makechunk(typename="proposition", thing="proposition", form="b:nB", element="b", mainconnective="negation", subformula1="B", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="x:nF", element="x", mainconnective="negation", subformula1="F", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="c:C", element="c", mainconnective="concept", subformula1="C", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="c:/Es.D", element="c", mainconnective="existential", relation="s", subformula1="y:D", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="y:D", element="y", mainconnective="concept", subformula1="D", derived="no"))
#5,95 #7,66

# %%
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="fredrik:teacher&supervisor", element="fredrik", mainconnective="conjunction", subformula1="fredrik:teacher", subformula2="fredrik:supervisor", derived="yes", inferred1="no", inferred2="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="tjeerd:student", element="tjeerd", mainconnective="concept", subformula1="student", derived="yes"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="graham:teacher&(supervisor&headofresearch)", element="graham", mainconnective="conjunction", subformula1="graham:teacher", subformula2="graham:supervisor&headofresearch", derived="yes"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="(tjeerd,fredrik):supervisedby", mainconnective="relation", relation="supervisedby", subformula1="tjeerd", subformula2="fredrik", derived="yes"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="tjeerd:student&employee", element="tjeerd", mainconnective="conjunction", subformula1="tjeerd:student", subformula2="tjeerd:employee", derived="yes", inferred1="no", inferred2="no"))

dm.add(actr.makechunk(typename="proposition", thing="proposition", form="fredrik:teacher", element="fredrik", mainconnective="concept", subformula1="teacher", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="fredrik:supervisor", element="fredrik", mainconnective="concept", subformula1="supervisor", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="graham:teacher", element="graham", mainconnective="concept", subformula1="teacher", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="graham:supervisor&headofresearch", element="graham", mainconnective="conjunction", subformula1="graham:supervisor", subformula2="graham:headofresearch", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="graham:supervisor", element="graham", mainconnective="concept", subformula1="supervisor", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="graham:headofresearch", mainconnective="concept", subformula1="headofresearch", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="tjeerd:student", element="tjeerd", mainconnective="concept", subformula1="student", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="tjeerd:employee", element="tjeerd", mainconnective="concept", subformula1="employee", derived="no"))
#16,35

# %%
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="fredrik:teacher&supervisor", element="fredrik", mainconnective="conjunction", subformula1="fredrik:teacher", subformula2="fredrik:supervisor", derived="yes", inferred1="no", inferred2="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="tjeerd:student", element="tjeerd", mainconnective="concept", subformula1="student", derived="yes"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="graham:teacher&(supervisor&headofresearch)", element="graham", mainconnective="conjunction", subformula1="graham:teacher", subformula2="graham:supervisor&headofresearch", derived="yes"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="(tjeerd,fredrik):supervisedby", mainconnective="relation", relation="supervisedby", subformula1="tjeerd", subformula2="fredrik", derived="yes"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="tjeerd:student&employee", element="tjeerd", mainconnective="conjunction", subformula1="tjeerd:student", subformula2="tjeerd:employee", derived="yes", inferred1="no", inferred2="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="graham:nheadofresearch", element="graham", mainconnective="negation", subformula1="headofresearch", derived="yes"))

dm.add(actr.makechunk(typename="proposition", thing="proposition", form="fredrik:teacher", element="fredrik", mainconnective="concept", subformula1="teacher", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="fredrik:supervisor", element="fredrik", mainconnective="concept", subformula1="supervisor", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="graham:teacher", element="graham", mainconnective="concept", subformula1="teacher", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="graham:supervisor&headofresearch", element="graham", mainconnective="conjunction", subformula1="graham:supervisor", subformula2="graham:headofresearch", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="graham:supervisor", element="graham", mainconnective="concept", subformula1="supervisor", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="graham:headofresearch", element="graham", mainconnective="concept", subformula1="headofresearch", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="tjeerd:student", element="tjeerd", mainconnective="concept", subformula1="student", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="tjeerd:employee", element="tjeerd", mainconnective="concept", subformula1="employee", derived="no"))
#9,5 #35,36

# %%
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="godel:(austrian&logician)&(Einsteinsfriend&incomplete)", element="godel", mainconnective="conjunction", subformula1="godel:austrian&logician", subformula2="godel:Einsteinsfriend&incomplete", derived="yes", inferred1="no", inferred2="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="godel:austrian&(logician&(Einsteinsfriend&incomplete))", element="godel", mainconnective="conjunction", subformula1="godel:austrian", subformula2="godel:logician&(Einsteinsfriend&incomplete)", derived="yes", inferred1="no", inferred2="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="godel:austrian&((logician&Einsteinsfriend)&incomplete)", element="godel", mainconnective="conjunction", subformula1="godel:austrian", subformula2="godel:(logician&Einsteinsfriend)&incomplete", derived="yes", inferred1="no", inferred2="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="godel:(austrian&(logician&Einsteinsfriend))&incomplete", element="godel", mainconnective="conjunction", subformula1="godel:austrian&(logician&Einsteinsfriend)", subformula2="godel:incomplete", derived="yes", inferred1="no", inferred2="no"))

dm.add(actr.makechunk(typename="proposition", thing="proposition", form="godel:austrian&logician", element="godel", mainconnective="conjunction", subformula1="godel:austrian", subformula2="godel:logician", derived="no", inferred1="no", inferred2="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="godel:Einsteinsfriend&incomplete", element="godel", mainconnective="conjunction", subformula1="godel:Einsteinsfriend", subformula2="godel:incomplete", derived="no", inferred1="no", inferred2="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="godel:austrian", element="godel", mainconnective="concept", subformula1="austrian", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="godel:logician", element="godel", mainconnective="concept", subformula1="logician", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="godel:Einsteinsfriend", element="godel", mainconnective="concept", subformula1="Einsteinsfriend", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="godel:incomplete", element="godel", mainconnective="concept", subformula1="incomplete", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="godel:logician&(Einsteinsfriend&incomplete)", element="godel", mainconnective="conjunction", subformula1="godel:logician", subformula2="godel:Einsteinsfriend&incomplete", derived="no", inferred1="no", inferred2="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="godel:(logician&Einsteinsfriend)&incomplete", element="godel", mainconnective="conjunction", subformula1="godel:logician&Einsteinsfriend", subformula2="godel:incomplete", derived="no", inferred1="no", inferred2="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="godel:austrian&(logician&Einsteinsfriend)", element="godel", mainconnective="conjunction", subformula1="godel:austrian", subformula2="godel:logician&Einsteinsfriend", derived="no", inferred1="no", inferred2="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="godel:logician&Einsteinsfriend", element="godel", mainconnective="conjunction", subformula1="godel:logician", subformula2="godel:Einsteinsfriend", derived="no", inferred1="no", inferred2="no"))
#32,85

# %%
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="visser:logician&(Enayatsfriend&(dutch&funny))", element="visser", mainconnective="conjunction", subformula1="visser:logician", subformula2="visser:Enayatsfriend&(dutch&funny)", derived="yes", inferred1="no", inferred2="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="visser:logician&(Enayatsfriend&(dutch&nfunny))", element="visser", mainconnective="conjunction", subformula1="visser:logician", subformula2="visser:Enayatsfriend&(dutch&nfunny)", derived="yes", inferred1="no", inferred2="no"))

dm.add(actr.makechunk(typename="proposition", thing="proposition", form="visser:logician", element="visser", mainconnective="concept", subformula1="logician", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="visser:Enayatsfriend&(dutch&nfunny)", element="visser", mainconnective="conjunction", subformula1="visser:Enayatsfriend", subformula2="visser:dutch&nfunny", derived="no", inferred1="no", inferred2="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="visser:Enayatsfriend", element="visser", mainconnective="concept", subformula1="Enayatsfriend", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="visser:dutch&nfunny", element="visser", mainconnective="conjunction", subformula1="visser:dutch", subformula2="visser:nfunny", derived="no", inferred1="no", inferred2="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="visser:dutch", element="visser", mainconnective="concept", subformula1="dutch", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="visser:nfunny", element="visser", mainconnective="negation", subformula1="funny", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="visser:dutch&funny", element="visser", mainconnective="conjunction", subformula1="visser:dutch", subformula2="visser:funny", derived="no", inferred1="no", inferred2="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="visser:funny", element="visser", mainconnective="concept", subformula1="funny", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="visser:Enayatsfriend&(dutch&funny)", element="visser", mainconnective="conjunction", subformula1="visser:Enayatsfriend", subformula2="visser:dutch&funny", derived="no", inferred1="no", inferred2="no"))
#15,2

# %%
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="giacomo:dutch", element="giacomo", mainconnective="concept", subformula1="dutch", derived="yes", relation="none", inferred1="none", subformula2="none", inferred2="none"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="giacomo:ndutch&(logician&footballplayer)", element="giacomo", mainconnective="conjunction", subformula1="giacomo:ndutch", subformula2="giacomo:logician&footballplayer", derived="yes", inferred1="no", inferred2="no"))

dm.add(actr.makechunk(typename="proposition", thing="proposition", form="giacomo:ndutch", element="giacomo", mainconnective="negation", subformula1="dutch", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="giacomo:logician&footballplayer", element="giacomo", mainconnective="conjunction", subformula1="giacomo:logician", subformula2="giacomo:footballplayer", derived="no", inferred1="no", inferred2="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="giacomo:logician", element="giacomo", mainconnective="concept", subformula1="logician", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="giacomo:footballplayer", element="giacomo", mainconnective="concept", subformula1="footballplayer", derived="no"))
#1,45 #2,5

# %%
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="giacomo:nfootballplayer", element="giacomo", mainconnective="negation", subformula1="footballplayer", derived="yes"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="giacomo:ndutch&(logician&footballplayer)", element="giacomo", mainconnective="conjunction", subformula1="giacomo:ndutch", subformula2="giacomo:logician&footballplayer", derived="yes", inferred1="no", inferred2="no"))

dm.add(actr.makechunk(typename="proposition", thing="proposition", form="giacomo:ndutch", element="giacomo", mainconnective="negation", subformula1="dutch", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="giacomo:logician&footballplayer", element="giacomo", mainconnective="conjunction", subformula1="giacomo:logician", subformula2="giacomo:footballplayer", derived="no", inferred1="no", inferred2="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="giacomo:logician", element="giacomo", mainconnective="concept", subformula1="logician", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="giacomo:footballplayer", element="giacomo", mainconnective="concept", subformula1="footballplayer", derived="no"))
#4,8 #6.44

# %%
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="a:A", element="a", mainconnective="concept", subformula1="A", derived="yes"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="a:A&(B&C)", element="a", mainconnective="conjunction", subformula1="a:A", subformula2="a:B&C", derived="yes", inferred1="no", inferred2="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="a:A&(D&E)", element="a", mainconnective="conjunction", subformula1="a:A", subformula2="a:D&E", derived="yes", inferred1="no", inferred2="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="a:A&(F&G)", element="a", mainconnective="conjunction", subformula1="a:A", subformula2="a:F&G", derived="yes", inferred1="no", inferred2="no"))

dm.add(actr.makechunk(typename="proposition", thing="proposition", form="a:B", element="a", mainconnective="concept", subformula1="B", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="a:C", element="a", mainconnective="concept", subformula1="C", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="a:B&C", element="a", mainconnective="conjunction", subformula1="a:B", subformula2="a:C", derived="no", inferred1="no", inferred2="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="a:D", element="a", mainconnective="concept", subformula1="D", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="a:E", element="a", mainconnective="concept", subformula1="E", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="a:D&E", element="a", mainconnective="conjunction", subformula1="a:D", subformula2="a:E", derived="no", inferred1="no", inferred2="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="a:F", element="a", mainconnective="concept", subformula1="F", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="a:G", element="a", mainconnective="concept", subformula1="G", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="a:F&G", element="a", mainconnective="conjunction", subformula1="a:F", subformula2="a:G", derived="no", inferred1="no", inferred2="no"))
#21,75

# %%
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="a:B&C", element="a", mainconnective="conjunction", subformula1="a:B", subformula2="a:C", derived="yes", inferred1="no", inferred2="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="a:D&E", element="a", mainconnective="conjunction", subformula1="a:D", subformula2="a:E", derived="yes", inferred1="no", inferred2="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="a:F&G", element="a", mainconnective="conjunction", subformula1="a:F", subformula2="a:G", derived="yes", inferred1="no", inferred2="no"))

dm.add(actr.makechunk(typename="proposition", thing="proposition", form="a:B", element="a", mainconnective="concept", subformula1="B", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="a:C", element="a", mainconnective="concept", subformula1="C", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="a:D", element="a", mainconnective="concept", subformula1="D", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="a:E", element="a", mainconnective="concept", subformula1="E", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="a:F", element="a", mainconnective="concept", subformula1="F", derived="no"))
dm.add(actr.makechunk(typename="proposition", thing="proposition", form="a:G", element="a", mainconnective="concept", subformula1="G", derived="no"))
#12,45

# %%
aBoxCon.productionstring(name="find first formula", string="""
    =g>
    isa     goal
    state   start
    =imaginal>
    isa     checklist
    thing   checklist
    # ?retrieval>
    state   free
    ==>
    =g>
    isa     goal
    state   store
    +retrieval>
    isa     proposition
    thing   proposition
    derived yes
    mainconnective ~disjunction
    mainconnective ~conjunction
    mainconnective ~relation
    mainconnective ~existential
    mainconnective ~universal
""")

aBoxCon.productionstring(name="skip and derive first formula", string="""
    =g>
    isa     goal
    state   store
    =imaginal>
    isa     checklist
    thing   checklist
    # ?retrieval>
    state   error
    ==>
    =g>
    isa      goal
    state    module2
    ~retrieval>
""")

aBoxCon.productionstring(name="store first formula", string="""
    =g>
    isa     goal
    state   store
    =imaginal>
    isa     checklist
    thing   checklist
    =retrieval>
    isa     proposition
    thing   proposition
    form    =U
    element  =X
    mainconnective =Y
    subformula1 =Z
    ==>
    =g>
    isa     goal
    state   find_clash
    +imaginal>
    isa     checklist
    thing   checklist
    form    =U
    element =X
    mainconnective =Y
    subformula1 =Z
    relation none
    subformula2 none
    form2   none
    form3   none
    form4   none
    form5   none
    form6   none
    form7   none
    form8   none
""")

aBoxCon.productionstring(name="find clash 1", string="""
    =g>
    isa     goal
    state   find_clash
    =imaginal>
    isa     checklist
    thing   checklist
    element =X
    mainconnective concept
    relation =G
    subformula1 =Y
    form    =Z
    form2   =A
    form3   =B
    form4   =C
    form5   =D
    form6   =E
    form7   =F
    # ?retrieval>
    state   free
    ==>
    =g>
    isa     goal
    state   signal_clash
    +imaginal>
    isa     checklist
    thing   checklist
    element =X
    mainconnective concept
    subformula1 =Y
    relation =G
    form    =Z
    form2   =A
    form3   =B
    form4   =C
    form5   =D
    form6   =E
    form7   =F
    +retrieval>
    isa     proposition
    thing   proposition
    element  =X
    mainconnective negation
    subformula1 =Y
    derived  yes
""")

aBoxCon.productionstring(name="show clash 1", string="""
    =g>
    isa     goal
    state   signal_clash
    =imaginal>
    isa     checklist
    thing   checklist
    element =X
    form    =X1
    mainconnective concept
    subformula1 =Y
    relation =Z1
    subformula2 =Z2
    form2   =Z3
    form3   =Z4
    form4   =Z5
    form5   =Z6
    form6   =Z7
    form7   =Z8
    form8   =Z9
    =retrieval>
    isa     proposition
    thing   proposition
    element  =X
    mainconnective negation
    subformula1 =Y
    # ?manual>
    state   free
    ==>
    =g>
    isa     goal
    state   stop
    +manual>
    isa     _manual
    cmd     press_key
    key     C
""")

aBoxCon.productionstring(name="no clash 1", string="""
    =g>
    isa     goal
    state   signal_clash
    =imaginal>
    isa     checklist
    thing   checklist
    form    =Z
    element =X
    mainconnective concept
    subformula1 =Y
    form2   =A
    form3   =B
    form4   =C
    form5   =D
    form6   =E
    form7   =F
    form8   =G
    relation =Z1
    subformula2 =Z2
    # ?retrieval>
    state   error
    ==>
    =g>
    isa     goal
    state   find_next_formula
    +imaginal>
    isa     checklist
    thing   checklist
    form    none
    element none
    mainconnective none
    subformula1 none
    subformula2 none
    relation none
    form2   =Z
    form3   =A
    form4   =B
    form5   =C
    form6   =D
    form7   =E
    form8   =F
    ~retrieval>
""")

aBoxCon.productionstring(name="find clash 2", string="""
    =g>
    isa     goal
    state   find_clash
    =imaginal>
    isa     checklist
    thing   checklist
    element =X
    mainconnective negation
    subformula1 =Y
    relation =G
    form    =Z
    form2   =A
    form3   =B
    form4   =C
    form5   =D
    form6   =E
    form7   =F
    # ?retrieval>
    state   free
    ==>
    =g>
    isa     goal
    state   signal_clash
    +imaginal>
    isa     checklist
    thing   checklist
    element =X
    mainconnective negation
    subformula1 =Y
    relation =G
    form    =Z
    form2   =A
    form3   =B
    form4   =C
    form5   =D
    form6   =E
    form7   =F
    +retrieval>
    isa     proposition
    thing   proposition
    element  =X
    mainconnective concept
    subformula1 =Y
    derived  yes
""")

aBoxCon.productionstring(name="show clash 2", string="""
    =g>
    isa     goal
    state   signal_clash
    =imaginal>
    isa     checklist
    thing   checklist
    element =X
    form    =X1
    mainconnective negation
    subformula1 =Y
    relation =Z1
    subformula2 =Z2
    form2  =Z3
    form3  =Z4
    form4  =Z5
    form5  =Z6
    form6  =Z7
    form7  =Z8
    form8  =Z9
    =retrieval>
    isa     proposition
    thing   proposition
    element  =X
    mainconnective concept
    subformula1 =Y
    # ?manual>
    state   free
    ==>
    =g>
    isa     goal
    state   stop
    +manual>
    isa     _manual
    cmd     press_key
    key     C
""")

aBoxCon.productionstring(name="no clash 2", string="""
    =g>
    isa     goal
    state   signal_clash
    =imaginal>
    isa     checklist
    thing   checklist
    form    =Z
    element =X
    mainconnective negation
    subformula1 =Y
    form2   =A
    form3   =B
    form4   =C
    form5   =D
    form6   =E
    form7   =F
    form8   =G
    relation =Z1
    subformula2 =Z2
    # ?retrieval>
    state   error
    ==>
    =g>
    isa     goal
    state   find_next_formula
    +imaginal>
    isa     checklist
    thing   checklist
    form    none
    element none
    mainconnective none
    subformula1 none
    subformula2 none
    relation none
    form2   =Z
    form3   =A
    form4   =B
    form5   =C
    form6   =D
    form7   =E
    form8   =F
    ~retrieval>
""")

aBoxCon.productionstring(name="find next formula", string="""
    =g>
    isa     goal
    state   find_next_formula
    =imaginal>
    isa     checklist
    thing   checklist
    form    =X1
    mainconnective =X2
    subformula1 =X3
    subformula2 =X4
    relation =X5
    element =X6
    form2   =U0
    form3   =U1
    form4   =U2
    form5   =U3
    form6   =U4
    form7   =U5
    form8   =U6
    # ?retrieval>
    state   free
    ==>
    =g>
    isa     goal
    state   decide
    +retrieval>
    isa     proposition
    thing   proposition
    derived yes
    form    ~=X1
    form    ~=U0
    form    ~=U1
    form    ~=U2
    form    ~=U3
    form    ~=U4
    form    ~=U5
    form    ~=U6
    mainconnective ~disjunction
    mainconnective ~conjunction
    mainconnective ~relation
    mainconnective ~existential
    mainconnective ~universal
    =imaginal>
    isa     checklist
    thing   checklist
    form    =X1
    mainconnective =X2
    subformula1 =X3
    subformula2 =X4
    relation =X5
    element =X6
    form2   =U0
    form3   =U1
    form4   =U2
    form5   =U3
    form6   =U4
    form7   =U5
    form8   =U6
""")

aBoxCon.productionstring(name="repeat", string="""
    =g>
    isa     goal
    state   decide
    =retrieval>
    isa     proposition
    element =X
    mainconnective =Y
    subformula1 =Z
    form    =U
    thing   proposition
    =imaginal>
    isa     checklist
    thing   checklist
    form    none
    element none
    mainconnective none
    subformula1 none
    subformula2 none
    relation none
    form2   =U0
    form3   =U1
    form4   =U2
    form5   =U3
    form6   =U4
    form7   =U5
    form8   =U6
    ==>
    =g>
    isa     goal
    state   find_clash
    +imaginal>
    isa     checklist
    thing   checklist
    form    =U
    element =X
    mainconnective =Y
    subformula1 =Z
    subformula2 none
    relation none
    form    =U
    form2   =U0
    form3   =U1
    form4   =U2
    form5   =U3
    form6   =U4
    form7   =U5
    form8   =U6
    ~retrieval>
""")

aBoxCon.productionstring(name="move on", string="""
    =g>
    isa     goal
    state   decide
    # ?retrieval>
    state   error
    ==>
    =g>
    isa     goal
    state   module2
    ~retrieval>
""")
# Out:
# {'=g': goal(state= decide), '?retrieval': {'state': 'error'}}
# ==>
# {'=g': goal(state= module2), '~retrieval': None}

# %%
aBoxCon.productionstring(name="find formula to apply rule to", string="""
    =g>
    isa      goal
    state    module2
    # ?retrieval>
    state   free
    ==>
    =g>
    isa     goal
    state   find_rule
    +retrieval>
    isa     proposition
    thing   proposition
    mainconnective  conjunction
    derived  yes
""")

aBoxCon.productionstring(name="conjunction found, first conjunct inferred? 1", string="""
    =g>
    isa      goal
    state    find_rule
    # ?retrieval>
    state    free
    =retrieval>
    isa      proposition
    thing    proposition
    form     =X
    element  =U
    mainconnective conjunction
    subformula1  =Y
    subformula2  =Z
    derived  yes
    ==>
    =g>
    isa      goal
    state    first_conjunct_inferred1
    +imaginal>
    isa      proposition
    thing    proposition
    form     =X
    element  =U
    mainconnective conjunction
    subformula1  =Y
    inferred1  no
    subformula2  =Z
    inferred2  no
    derived  yes
    relation none
    ~retrieval>
""")

aBoxCon.productionstring(name="conjunction found, first conjunct inferred? 2", string="""
    =g>
    isa      goal
    state    first_conjunct_inferred1
    =imaginal>
    isa      proposition
    thing    proposition
    form     =X
    element  =U
    mainconnective conjunction
    subformula1  =Y
    inferred1  no
    subformula2  =Z
    inferred2  no
    derived  yes
    relation none
    # ?retrieval>
    state    free
    ==>
    =g>
    isa      goal
    state    first_conjunct_inferred2
    +retrieval>
    isa      proposition
    thing    proposition
    form     =X
    mainconnective conjunction
    inferred1 yes
    =imaginal>
    isa      proposition
    thing    proposition
    form     =X
    element  =U
    mainconnective conjunction
    subformula1  =Y
    inferred1  no
    subformula2  =Z
    inferred2  no
    derived  yes
    relation none
""")

aBoxCon.productionstring(name="label first conjunct as inferred", string="""
    =g>
    isa      goal
    state    first_conjunct_inferred2
    # ?retrieval>
    state    error
    =imaginal>
    isa      proposition
    thing    proposition
    form     =X
    element  =U
    mainconnective conjunction
    subformula1  =Y
    subformula2  =Z
    derived  yes
    relation none
    ==>
    =g>
    isa      goal
    state    retrieve_first_conjunct
    +imaginal>
    isa      proposition
    thing    proposition
    form     =X
    element  =U
    mainconnective conjunction
    subformula1  =Y
    subformula2  =Z
    derived  yes
    inferred1  yes
    inferred2  none
    relation   none
    ~retrieval>
""")

aBoxCon.productionstring(name="retrieve first conjunct", string="""
    =g>
    isa      goal
    state    retrieve_first_conjunct
    =imaginal>
    isa      proposition
    thing    proposition
    form     =X
    element  =U
    mainconnective conjunction
    subformula1  =Y
    subformula2  =Z
    derived  yes
    inferred1  yes
    # ?retrieval>
    state    free
    ==>
    =g>
    isa      goal
    state    label_first_conjunct
    +retrieval>
    isa      proposition
    thing    proposition
    form     =Y
    ~imaginal>
""")

aBoxCon.productionstring(name="label first conjunct as derived", string="""
    =g>
    isa      goal
    state    label_first_conjunct
    =retrieval>
    isa      proposition
    thing    proposition
    form     =X
    element  =U
    mainconnective =V
    subformula1  =Y
    subformula2  =Z
    # ?imaginal>
    state    free
    ==>
    =g>
    isa      goal
    state    module3
    +imaginal>
    isa      proposition
    thing    proposition
    form     =X
    element  =U
    mainconnective =V
    subformula1  =Y
    subformula2  =Z
    derived  yes
    relation none
    inferred1 none
    inferred2 none
""")

aBoxCon.productionstring(name="second_conjunct_inferred_a", string="""
    =g>
    isa      goal
    state    first_conjunct_inferred2
    # ?retrieval>
    buffer   full
    # ?retrieval>
    state    free
    =retrieval>
    isa      proposition
    thing    proposition
    form     =X
    element  =Y
    mainconnective conjunction
    subformula1 =U
    inferred1 yes
    subformula2 =V
    inferred2 =W
    derived   =Z
    relation none
    # ?imaginal>
    state    free
    =imaginal>
    isa      proposition
    thing    proposition
    form     =T1
    element  =T2
    mainconnective conjunction
    subformula1  =T3
    inferred1  no
    subformula2  =T4
    inferred2  no
    derived  yes
    relation none
    ==>
    =g>
    isa      goal
    state    pre_infer_second_conjunct_after_first
    +imaginal>
    isa      proposition
    thing    proposition
    form     =X
    element  =Y
    mainconnective conjunction
    subformula1 =U
    inferred1 yes
    subformula2 =V
    inferred2 =W
    derived   =Z
    relation  none
    ~retrieval>
""")

aBoxCon.productionstring(name="second_conjunct_inferred_b", string="""
    =g>
    isa      goal
    state    pre_infer_second_conjunct_after_first
    =imaginal>
    isa      proposition
    thing    proposition
    form     =X
    element  =Y
    mainconnective conjunction
    subformula1 =U
    inferred1 yes
    subformula2 =V
    inferred2 =W
    derived   =Z
    relation none
    # ?retrieval>
    state    free
    ==>
    =g>
    isa      goal
    state    infer_second_conjunct_after_first
    +retrieval>
    isa      proposition
    thing    proposition
    form     =X
    element  =Y
    mainconnective conjunction
    subformula1 =U
    inferred1 yes
    subformula2 =V
    inferred2 yes
    derived   =Z
    =imaginal>
    isa      proposition
    thing    proposition
    form     =X
    element  =Y
    mainconnective conjunction
    subformula1 =U
    inferred1 yes
    subformula2 =V
    inferred2 =W
    derived   =Z
    relation  none
""")

aBoxCon.productionstring(name="store in list 1", string="""
    =g>
    isa      goal
    state    infer_second_conjunct_after_first
    =retrieval>
    isa      proposition
    thing    proposition
    form     =X
    element  =Y
    mainconnective =Z
    relation =U
    subformula1 =V
    subformula2 =W
    inferred1 yes
    inferred2 yes
    # ?retrieval>
    state    free
    ==>
    =g>
    isa      goal
    state    store_in_list
    +imaginal>
    isa      storelist
    thing    storelist
    form     =X
    element  =Y
    mainconnective =Z
    relation =U
    subformula1 =V
    subformula2 =W
    derived  none
    inferred1 none
    inferred2 none
    form2    none
    form3    none
    form4    none
    form5    none
    form6    none
    form7    none
    form8    none
    form9    none
    form10   none
    form11   none
    form12   none
    form13   none
    form14   none
    form15   none
""")

aBoxCon.productionstring(name="label second conjunct as inferred after first", string="""
    =g>
    isa      goal
    state    infer_second_conjunct_after_first
    # ?retrieval>
    state    error
    =imaginal>
    isa      proposition
    thing    proposition
    form     =X
    element  =U
    mainconnective conjunction
    subformula1  =Y
    subformula2  =Z
    derived  yes
    relation none
    inferred1 =S1
    inferred2 =S2
    ==>
    =g>
    isa      goal
    state    retrieve_second_conjunct_after_first
    +imaginal>
    isa      proposition
    thing    proposition
    form     =X
    element  =U
    mainconnective conjunction
    subformula1  =Y
    subformula2  =Z
    derived  yes
    inferred1 yes
    inferred2 yes
    relation  none
    ~retrieval>
""")

aBoxCon.productionstring(name="retrieve second conjunct after first", string="""
    =g>
    isa      goal
    state    retrieve_second_conjunct_after_first
    =imaginal>
    isa      proposition
    thing    proposition
    form     =X
    element  =U
    mainconnective conjunction
    subformula1  =Y
    subformula2  =Z
    derived  yes
    inferred1 yes
    inferred2 yes
    relation  none
    # ?retrieval>
    state    free
    ==>
    =g>
    isa      goal
    state    label_second_conjunct_after_first
    +retrieval>
    isa      proposition
    thing    proposition
    form     =Z
    element  =U
    derived  no
    +imaginal>
    isa      proposition
    thing    proposition
    form     =X
    element  =U
    mainconnective conjunction
    subformula1  =Y
    subformula2  =Z
    derived  yes
    inferred1 yes
    inferred2 yes
    relation  none
""")

aBoxCon.productionstring(name="label second conjunct as derived after first", string="""
    =g>
    isa      goal
    state    label_second_conjunct_after_first
    # ?retrieval>
    state    free
    =retrieval>
    isa      proposition
    thing    proposition
    form     =X
    element  =U
    mainconnective =V
    subformula1  =Y
    subformula2  =Z
    relation  =S
    inferred1  =S1
    inferred2  =S2
    # ?imaginal>
    state    free
    ==>
    =g>
    isa      goal
    state    module3
    +imaginal>
    isa      proposition
    thing    proposition
    form     =X
    element  =U
    mainconnective =V
    subformula1  =Y
    subformula2  =Z
    derived  yes
    relation  =S
    inferred1 =S1
    inferred2 =S2
""")


#--------------------------------------------------------------------------------------------------


aBoxCon.productionstring(name="conjunction found, second conjunct inferred? 1", string="""
    =g>
    isa      goal
    state    find_rule
    # ?retrieval>
    state    free
    =retrieval>
    isa      proposition
    thing    proposition
    form     =X
    element  =U
    mainconnective conjunction
    subformula1  =Y
    subformula2  =Z
    derived  yes
    ==>
    =g>
    isa      goal
    state    second_conjunct_inferred1
    +imaginal>
    isa      proposition
    thing    proposition
    form     =X
    element  =U
    mainconnective conjunction
    subformula1  =Y
    inferred1  no
    subformula2  =Z
    inferred2  no
    derived  yes
    relation none
    ~retrieval>
""")

aBoxCon.productionstring(name="conjunction found, second conjunct inferred? 2", string="""
    =g>
    isa      goal
    state    second_conjunct_inferred1
    =imaginal>
    isa      proposition
    thing    proposition
    form     =X
    element  =U
    mainconnective conjunction
    subformula1  =Y
    inferred1  no
    subformula2  =Z
    inferred2  no
    derived  yes
    relation none
    # ?retrieval>
    state    free
    ==>
    =g>
    isa      goal
    state    second_conjunct_inferred2
    +retrieval>
    isa      proposition
    thing    proposition
    form     =X
    mainconnective conjunction
    inferred2 yes
    =imaginal>
    isa      proposition
    thing    proposition
    form     =X
    element  =U
    mainconnective conjunction
    subformula1  =Y
    inferred1  no
    subformula2  =Z
    inferred2  no
    derived  yes
    relation none
""")

aBoxCon.productionstring(name="label second conjunct as inferred", string="""
    =g>
    isa      goal
    state    second_conjunct_inferred2
    # ?retrieval>
    state    error
    =imaginal>
    isa      proposition
    thing    proposition
    form     =X
    element  =U
    mainconnective conjunction
    subformula1  =Y
    subformula2  =Z
    derived  yes
    relation none
    ==>
    =g>
    isa      goal
    state    retrieve_second_conjunct
    +imaginal>
    isa      proposition
    thing    proposition
    form     =X
    element  =U
    mainconnective conjunction
    subformula1  =Y
    subformula2  =Z
    derived  yes
    inferred2  yes
    inferred1  none
    relation   none
    ~retrieval>
""")

aBoxCon.productionstring(name="retrieve second conjunct", string="""
    =g>
    isa      goal
    state    retrieve_second_conjunct
    =imaginal>
    isa      proposition
    thing    proposition
    form     =X
    element  =U
    mainconnective conjunction
    subformula1  =Y
    subformula2  =Z
    derived  yes
    inferred2  yes
    # ?retrieval>
    state    free
    ==>
    =g>
    isa      goal
    state    label_second_conjunct
    +retrieval>
    isa      proposition
    thing    proposition
    form     =Z
""")

aBoxCon.productionstring(name="label second conjunct as derived", string="""
    =g>
    isa      goal
    state    label_second_conjunct
    =retrieval>
    isa      proposition
    thing    proposition
    form     =X
    element  =U
    mainconnective =V
    subformula1  =Y
    subformula2  =Z
    # ?imaginal>
    state    free
    ==>
    =g>
    isa      goal
    state    module3
    +imaginal>
    isa      proposition
    thing    proposition
    form     =X
    element  =U
    mainconnective =V
    subformula1  =Y
    subformula2  =Z
    derived  yes
    relation  none
    inferred1 none
    inferred2 none
""")

aBoxCon.productionstring(name="first_conjunct_inferred_a", string="""
    =g>
    isa      goal
    state    second_conjunct_inferred2
    # ?retrieval>
    buffer   full
    # ?retrieval>
    state    free
    =retrieval>
    isa      proposition
    thing    proposition
    form     =X
    element  =Y
    mainconnective conjunction
    subformula1 =U
    inferred1 =W
    subformula2 =V
    inferred2 yes
    derived   =Z
    relation none
    # ?imaginal>
    state    free
    ==>
    =g>
    isa      goal
    state    pre_infer_first_conjunct_after_second
    +imaginal>
    isa      proposition
    thing    proposition
    form     =X
    element  =Y
    mainconnective conjunction
    subformula1 =U
    inferred1 =W
    subformula2 =V
    inferred2 yes
    derived   =Z
    relation  none
    ~retrieval>
""")

aBoxCon.productionstring(name="first_conjunct_inferred_b", string="""
    =g>
    isa      goal
    state    pre_infer_first_conjunct_after_second
    =imaginal>
    isa      proposition
    thing    proposition
    form     =X
    element  =Y
    mainconnective conjunction
    subformula1 =U
    inferred1 =W
    subformula2 =V
    inferred2 yes
    derived   =Z
    relation  none
    # ?retrieval>
    state    free
    ==>
    =g>
    isa      goal
    state    infer_first_conjunct_after_second
    +retrieval>
    isa      proposition
    thing    proposition
    form     =X
    element  =Y
    mainconnective conjunction
    subformula1 =U
    inferred1 yes
    subformula2 =V
    inferred2 yes
    derived   =Z
    =imaginal>
    isa      proposition
    thing    proposition
    form     =X
    element  =Y
    mainconnective conjunction
    subformula1 =U
    inferred1 =W
    subformula2 =V
    inferred2 yes
    derived   =Z
    relation  none
""")

aBoxCon.productionstring(name="store in list 2", string="""
    =g>
    isa      goal
    state    infer_first_conjunct_after_second
    =retrieval>
    isa      proposition
    thing    proposition
    form     =X
    element  =Y
    mainconnective =Z
    relation =U
    subformula1 =V
    subformula2 =W
    inferred1 yes
    inferred2 yes
    # ?retrieval>
    state    free
    ==>
    =g>
    isa      goal
    state    store_in_list
    +imaginal>
    isa      storelist
    thing    storelist
    form     =X
    element  =Y
    mainconnective =Z
    relation =U
    subformula1 =V
    subformula2 =W
    derived  none
    inferred1  none
    inferred2  none
    form2    none
    form3    none
    form4    none
    form5    none
    form6    none
    form7    none
    form8    none
    form9    none
    form10   none
    form11   none
    form12   none
    form13   none
    form14   none
    form15   none
""")

aBoxCon.productionstring(name="label first conjunct as inferred after second", string="""
    =g>
    isa      goal
    state    infer_first_conjunct_after_second
    # ?retrieval>
    state    error
    =imaginal>
    isa      proposition
    thing    proposition
    form     =X
    element  =U
    mainconnective conjunction
    subformula1  =Y
    subformula2  =Z
    derived  yes
    relation none
    inferred1 =S1
    inferred2 =S2
    ==>
    =g>
    isa      goal
    state    retrieve_first_conjunct_after_second
    +imaginal>
    isa      proposition
    thing    proposition
    form     =X
    element  =U
    mainconnective conjunction
    subformula1  =Y
    subformula2  =Z
    derived  yes
    inferred1 yes
    inferred2 yes
    relation  none
    ~retrieval>
""")

aBoxCon.productionstring(name="retrieve first conjunct after second", string="""
    =g>
    isa      goal
    state    retrieve_first_conjunct_after_second
    =imaginal>
    isa      proposition
    thing    proposition
    form     =X
    element  =U
    mainconnective conjunction
    subformula1  =Y
    subformula2  =Z
    derived  yes
    inferred1 yes
    inferred2 yes
    relation  none
    # ?retrieval>
    state    free
    ==>
    =g>
    isa      goal
    state    label_first_conjunct_after_second
    +retrieval>
    isa      proposition
    thing    proposition
    form     =Y
    derived  no
    element  =U
    +imaginal>
    isa      proposition
    thing    proposition
    form     =X
    element  =U
    mainconnective conjunction
    subformula1  =Y
    subformula2  =Z
    derived  yes
    inferred1 yes
    inferred2 yes
    relation  none
""")

aBoxCon.productionstring(name="label first conjunct as derived after second", string="""
    =g>
    isa      goal
    state    label_first_conjunct_after_second
    # ?retrieval>
    state    free
    =retrieval>
    isa      proposition
    thing    proposition
    form     =X
    element  =U
    mainconnective =V
    subformula1  =Y
    subformula2  =Z
    relation  =S
    inferred1  =S1
    inferred2  =S2
    # ?imaginal>
    state    free
    ==>
    =g>
    isa      goal
    state    module3
    +imaginal>
    isa      proposition
    thing    proposition
    form     =X
    element  =U
    mainconnective =V
    subformula1  =Y
    subformula2  =Z
    derived  yes
    relation   =S
    inferred1  =S1
    inferred2  =S2
""")
# Out:
# {'=g': goal(state= label_first_conjunct_after_second), '?retrieval': {'state': 'free'}, '=retrieval': proposition(derived= , element= =U, form= =X, inferred1= =S1, inferred2= =S2, mainconnective= =V, relation= =S, subformula1= =Y, subformula2= =Z, thing= proposition), '?imaginal': {'state': 'free'}}
# ==>
# {'=g': goal(state= module3), '+imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= =S1, inferred2= =S2, mainconnective= =V, relation= =S, subformula1= =Y, subformula2= =Z, thing= proposition)}

# %%
aBoxCon.productionstring(name="do we need to check for a clash? concept found", string="""
    =g>
    isa      goal
    state    module3
    =imaginal>
    isa      proposition
    thing    proposition
    form     =X
    element  =U
    mainconnective concept
    subformula1  =Y
    derived  yes
    ==>
    =g>
    isa      goal
    state    find_clash
    +imaginal>
    isa      checklist
    thing    checklist
    form     =X
    mainconnective concept
    element  =U
    subformula1 =Y
    relation none
    subformula2 none
    form2    none
    form3    none
    form4    none
    form5    none
    form6    none
    form7    none
    form8    none
    ~retrieval>
""")

aBoxCon.productionstring(name="do we need to check for a clash? negation found", string="""
    =g>
    isa      goal
    state    module3
    =imaginal>
    isa      proposition
    thing    proposition
    form     =X
    element  =U
    mainconnective negation
    subformula1  =Y
    derived  yes
    ==>
    =g>
    isa      goal
    state    find_clash
    +imaginal>
    isa      checklist
    thing    checklist
    mainconnective negation
    element  =U
    subformula1 =Y
    form     =X
    relation none
    subformula2 none
    form2    none
    form3    none
    form4    none
    form5    none
    form6    none
    form7    none
    form8    none
    ~retrieval>
""")
    
aBoxCon.productionstring(name="do we need to derive something new?", string="""
    =g>
    isa      goal
    state    module3
    =imaginal>
    isa      proposition
    thing    proposition
    element  =X
    subformula1 =Y
    form     =Z
    mainconnective ~concept
    mainconnective ~negation
    ==>
    =g>
    isa      goal
    state    module2
    ~imaginal>
    ~retrieval>
""")
# Out:
# {'=g': goal(state= module3), '=imaginal': proposition(derived= , element= =X, form= =Z, inferred1= , inferred2= , mainconnective= ~negation~concept, relation= , subformula1= =Y, subformula2= , thing= proposition)}
# ==>
# {'=g': goal(state= module2), '~imaginal': None, '~retrieval': None}

# %%
aBoxCon.productionstring(name="retrieve the next proposition to store in the list", string="""
    =g>
    isa      goal
    state    store_in_list
    =imaginal>
    isa      storelist
    thing    storelist
    form     =X
    element  =Y
    mainconnective =Z
    relation =U
    subformula1 =V
    subformula2 =W
    form2    =T1
    form3    =T2
    form4    =T3
    form5    =T4
    form6    =T5
    form7    =T6
    form8    =T7
    form9    =T8
    form10   =T9
    form11   =T10
    form12   =T11
    form13   =T12
    form14   =T13
    form15   =T14
    derived  =S1
    inferred1 =S2
    inferred2 =S3
    # ?retrieval>
    state    free
    ==>
    =g>
    isa      goal
    state    store_in_list2
    +retrieval>
    isa      proposition
    thing    proposition
    form     ~=X
    form     ~=T1
    form     ~=T2
    form     ~=T3
    form     ~=T4
    form     ~=T5
    form     ~=T6
    form     ~=T7
    form     ~=T8
    form     ~=T9
    form     ~=T10
    form     ~=T11
    form     ~=T12
    form     ~=T13
    form     ~=T14
    derived  yes
    inferred1 yes
    inferred2 yes
""")

aBoxCon.productionstring(name="store the next proposition in the list", string="""
    =g>
    isa      goal
    state    store_in_list2
    =imaginal>
    isa      storelist
    thing    storelist
    form     =X
    element  =Y
    mainconnective =Z
    relation =U
    subformula1 =V
    subformula2 =W
    form2    =T1
    form3    =T2
    form4    =T3
    form5    =T4
    form6    =T5
    form7    =T6
    form8    =T7
    form9    =T8
    form10   =T9
    form11   =T10
    form12   =T11
    form13   =T12
    form14   =T13
    derived   =S1
    inferred1 =S2
    inferred2 =S3
    form15    =S4
    # ?retrieval>
    state    free
    =retrieval>
    isa      proposition
    thing    proposition
    form     =X2
    derived  yes
    inferred1 yes
    inferred2 yes
    element  =Y2
    mainconnective =Z2
    relation =U2
    subformula1 =V2
    subformula2 =W2
    ==>
    =g>
    isa      goal
    state    store_in_list
    +imaginal>
    isa      storelist
    thing    storelist
    element  =Y2
    mainconnective =Z2
    relation =U2
    subformula1 =V2
    subformula2 =W2
    form     =X2
    form2    =X
    form3    =T1
    form4    =T2
    form5    =T3
    form6    =T4
    form7    =T5
    form8    =T6
    form9    =T7
    form10   =T8
    form11   =T9
    form12   =T11
    form13   =T11
    form14   =T12
    form15   =T13
    derived  yes
    inferred1 yes
    inferred2 yes
""")

aBoxCon.productionstring(name="use the list to select the next formula", string="""
    =g>
    isa      goal
    state    store_in_list2
    =imaginal>
    isa      storelist
    thing    storelist
    form     =X
    element  =Y
    mainconnective =Z
    relation =U
    subformula1 =V
    subformula2 =W
    form2    =T1
    form3    =T2
    form4    =T3
    form5    =T4
    form6    =T5
    form7    =T6
    form8    =T7
    form9    =T8
    form10   =T9
    form11   =T10
    form12   =T11
    form13   =T12
    form14   =T13
    derived   =S1
    inferred1 =S2
    inferred2 =S3
    form15    =S4
    # ?retrieval>
    state    error
    ==>
    =g>
    isa     goal
    state   find_rule
    +retrieval>
    isa     proposition
    thing   proposition
    form     ~=X
    form     ~=T1
    form     ~=T2
    form     ~=T3
    form     ~=T4
    form     ~=T5
    form     ~=T6
    form     ~=T7
    form     ~=T8
    form     ~=T9
    form     ~=T10
    form     ~=T11
    form     ~=T12
    form     ~=T13
    form     ~=S4
    mainconnective  conjunction
    derived  yes
""")

aBoxCon.productionstring(name="confirm consistency", string="""
    =g>
    isa      goal
    state    find_rule
    # ?retrieval>
    state    error
    ==>
    =g>
    isa     goal
    state   stop
    +manual>
    isa     _manual
    cmd     press_key
    key     N
""")
# Out:
# {'=g': goal(state= find_rule), '?retrieval': {'state': 'error'}}
# ==>
# {'=g': goal(state= stop), '+manual': _manual(cmd= press_key, key= N)}

# %%
aBoxCon_sim = aBoxCon.simulation(realtime=False,gui=False)

# %%
aBoxCon_sim.run(40)
# Out:
# (0, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (0, 'PROCEDURAL', 'RULE SELECTED: find first formula')
# (0.05, 'PROCEDURAL', 'RULE FIRED: find first formula')
# (0.05, 'g', 'MODIFIED')
# (0.05, 'retrieval', 'START RETRIEVAL')
# (Partially) matching chunk: proposition(derived= yes, element= b, form= b:B, inferred1= , inferred2= , mainconnective= concept, relation= , subformula1= B, subformula2= , thing= proposition)
# Base level learning: 0.0
# Spreading activation 0
# Partial matching 0
# Noise: 0
# Total activation 0.0
# Time to retrieve 0.1
# (0.05, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (0.05, 'PROCEDURAL', 'NO RULE FOUND')
# (0.15, 'retrieval', 'CLEARED')
# (0.15, 'retrieval', 'RETRIEVED: proposition(derived= yes, element= b, form= b:B, inferred1= , inferred2= , mainconnective= concept, relation= , subformula1= B, subformula2= , thing= proposition)')
# (0.15, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (0.15, 'PROCEDURAL', 'RULE SELECTED: store first formula')
# (0.2, 'PROCEDURAL', 'RULE FIRED: store first formula')
# (0.2, 'g', 'MODIFIED')
# (0.2, 'imaginal', 'CLEARED')
# (0.2, 'imaginal', 'CREATED A CHUNK: checklist(element= b, form2= none, form3= none, form4= none, form5= none, form6= none, form7= none, form8= none, form= b:B, mainconnective= concept, relation= none, subformula1= B, subformula2= none, thing= checklist)')
# (0.2, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (0.2, 'PROCEDURAL', 'RULE SELECTED: find clash 1')
# (0.25, 'PROCEDURAL', 'RULE FIRED: find clash 1')
# (0.25, 'g', 'MODIFIED')
# (0.25, 'imaginal', 'CLEARED')
# (0.25, 'retrieval', 'START RETRIEVAL')
# (0.25, 'imaginal', 'CREATED A CHUNK: checklist(element= b, form2= none, form3= none, form4= none, form5= none, form6= none, form7= none, form8= , form= b:B, mainconnective= concept, relation= none, subformula1= B, subformula2= , thing= checklist)')
# (0.25, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (0.25, 'PROCEDURAL', 'NO RULE FOUND')
# (0.35, 'retrieval', 'RETRIEVED: None')
# (0.35, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (0.35, 'PROCEDURAL', 'RULE SELECTED: no clash 1')
# (0.4, 'PROCEDURAL', 'RULE FIRED: no clash 1')
# (0.4, 'g', 'MODIFIED')
# (0.4, 'retrieval', 'CLEARED')
# (0.4, 'imaginal', 'CLEARED')
# (0.4, 'imaginal', 'CREATED A CHUNK: checklist(element= none, form2= b:B, form3= none, form4= none, form5= none, form6= none, form7= none, form8= none, form= none, mainconnective= none, relation= none, subformula1= none, subformula2= none, thing= checklist)')
# (0.4, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (0.4, 'PROCEDURAL', 'RULE SELECTED: find next formula')
# (0.45, 'PROCEDURAL', 'RULE FIRED: find next formula')
# (0.45, 'g', 'MODIFIED')
# (0.45, 'imaginal', 'MODIFIED')
# (0.45, 'retrieval', 'START RETRIEVAL')
# (0.45, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (0.45, 'PROCEDURAL', 'NO RULE FOUND')
# (0.55, 'retrieval', 'RETRIEVED: None')
# (0.55, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (0.55, 'PROCEDURAL', 'RULE SELECTED: move on')
# (0.6, 'PROCEDURAL', 'RULE CREATED: no clash 1 and find next formula')
# (0.6, 'PROCEDURAL', 'RULE FIRED: move on')
# (0.6, 'g', 'MODIFIED')
# (0.6, 'retrieval', 'CLEARED')
# (0.6, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (0.6, 'PROCEDURAL', 'RULE SELECTED: find formula to apply rule to')
# (0.65, 'PROCEDURAL', 'RULE FIRED: find formula to apply rule to')
# (0.65, 'g', 'MODIFIED')
# (0.65, 'retrieval', 'START RETRIEVAL')
# (Partially) matching chunk: proposition(derived= yes, element= a, form= a:A&/Es.F, inferred1= no, inferred2= no, mainconnective= conjunction, relation= , subformula1= a:A, subformula2= a:/Es.F, thing= proposition)
# Base level learning: 0.0
# Spreading activation 0
# Partial matching 0
# Noise: 0
# Total activation 0.0
# Time to retrieve 0.1
# (0.65, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (0.65, 'PROCEDURAL', 'NO RULE FOUND')
# (0.75, 'retrieval', 'CLEARED')
# (0.75, 'retrieval', 'RETRIEVED: proposition(derived= yes, element= a, form= a:A&/Es.F, inferred1= no, inferred2= no, mainconnective= conjunction, relation= , subformula1= a:A, subformula2= a:/Es.F, thing= proposition)')
# (0.75, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (0.75, 'PROCEDURAL', 'RULE SELECTED: conjunction found, second conjunct inferred? 1')
# (0.8, 'PROCEDURAL', 'RULE CREATED: move on and find formula to apply rule to')
# (0.8, 'PROCEDURAL', 'RULE FIRED: conjunction found, second conjunct inferred? 1')
# (0.8, 'g', 'MODIFIED')
# (0.8, 'retrieval', 'CLEARED')
# (0.8, 'imaginal', 'CLEARED')
# (0.8, 'imaginal', 'CREATED A CHUNK: proposition(derived= yes, element= a, form= a:A&/Es.F, inferred1= no, inferred2= no, mainconnective= conjunction, relation= none, subformula1= a:A, subformula2= a:/Es.F, thing= proposition)')
# (0.8, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (0.8, 'PROCEDURAL', 'RULE SELECTED: conjunction found, second conjunct inferred? 2')
# (0.85, 'PROCEDURAL', 'RULE CREATED: find formula to apply rule to and conjunction found, second conjunct inferred? 1')
# (0.85, 'PROCEDURAL', 'RULE FIRED: conjunction found, second conjunct inferred? 2')
# (0.85, 'g', 'MODIFIED')
# (0.85, 'imaginal', 'MODIFIED')
# (0.85, 'retrieval', 'START RETRIEVAL')
# (0.85, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (0.85, 'PROCEDURAL', 'NO RULE FOUND')
# (0.95, 'retrieval', 'RETRIEVED: None')
# (0.95, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (0.95, 'PROCEDURAL', 'RULE SELECTED: label second conjunct as inferred')
# (1.0, 'PROCEDURAL', 'RULE CREATED: conjunction found, second conjunct inferred? 1 and conjunction found, second conjunct inferred? 2')
# (1.0, 'PROCEDURAL', 'RULE FIRED: label second conjunct as inferred')
# (1.0, 'g', 'MODIFIED')
# (1.0, 'retrieval', 'CLEARED')
# (1.0, 'imaginal', 'CLEARED')
# (1.0, 'imaginal', 'CREATED A CHUNK: proposition(derived= yes, element= a, form= a:A&/Es.F, inferred1= none, inferred2= yes, mainconnective= conjunction, relation= none, subformula1= a:A, subformula2= a:/Es.F, thing= proposition)')
# (1.0, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (1.0, 'PROCEDURAL', 'RULE SELECTED: retrieve second conjunct')
# (1.05, 'PROCEDURAL', 'RULE FIRED: retrieve second conjunct')
# (1.05, 'g', 'MODIFIED')
# (1.05, 'retrieval', 'START RETRIEVAL')
# (Partially) matching chunk: proposition(derived= no, element= a, form= a:/Es.F, inferred1= , inferred2= , mainconnective= existential, relation= s, subformula1= x:F, subformula2= , thing= proposition)
# Base level learning: 0.0
# Spreading activation 0
# Partial matching 0
# Noise: 0
# Total activation 0.0
# Time to retrieve 0.1
# (1.05, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (1.05, 'PROCEDURAL', 'NO RULE FOUND')
# (1.15, 'retrieval', 'CLEARED')
# (1.15, 'retrieval', 'RETRIEVED: proposition(derived= no, element= a, form= a:/Es.F, inferred1= , inferred2= , mainconnective= existential, relation= s, subformula1= x:F, subformula2= , thing= proposition)')
# (1.15, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (1.15, 'PROCEDURAL', 'RULE SELECTED: label second conjunct as derived')
# (1.2, 'PROCEDURAL', 'RULE CREATED: label second conjunct as inferred and retrieve second conjunct')
# (1.2, 'PROCEDURAL', 'RULE FIRED: label second conjunct as derived')
# (1.2, 'g', 'MODIFIED')
# (1.2, 'imaginal', 'CLEARED')
# (1.2, 'imaginal', 'CREATED A CHUNK: proposition(derived= yes, element= a, form= a:/Es.F, inferred1= none, inferred2= none, mainconnective= existential, relation= none, subformula1= x:F, subformula2= None, thing= proposition)')
# (1.2, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (1.2, 'PROCEDURAL', 'RULE SELECTED: do we need to derive something new?')
# (1.25, 'PROCEDURAL', 'RULE FIRED: do we need to derive something new?')
# (1.25, 'g', 'MODIFIED')
# (1.25, 'imaginal', 'CLEARED')
# (1.25, 'retrieval', 'CLEARED')
# (1.25, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (1.25, 'PROCEDURAL', 'RULE SELECTED: find formula to apply rule to and conjunction found, second conjunct inferred? 1')
# (1.3, 'PROCEDURAL', 'RULE CREATED: label second conjunct as derived and do we need to derive something new?')
# (1.3, 'PROCEDURAL', 'RULE FIRED: find formula to apply rule to and conjunction found, second conjunct inferred? 1')
# (1.3, 'g', 'MODIFIED')
# (1.3, 'retrieval', 'CLEARED')
# (1.3, 'imaginal', 'CLEARED')
# (1.3, 'imaginal', 'CREATED A CHUNK: proposition(derived= yes, element= a, form= a:A&/Es.F, inferred1= no, inferred2= no, mainconnective= conjunction, relation= none, subformula1= a:A, subformula2= a:/Es.F, thing= proposition)')
# (1.3, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (1.3, 'PROCEDURAL', 'RULE SELECTED: conjunction found, second conjunct inferred? 2')
# (1.35, 'PROCEDURAL', 'RULE CREATED: do we need to derive something new? and find formula to apply rule to and conjunction found, second conjunct inferred? 1')
# (1.35, 'PROCEDURAL', 'RULE FIRED: conjunction found, second conjunct inferred? 2')
# (1.35, 'g', 'MODIFIED')
# (1.35, 'imaginal', 'MODIFIED')
# (1.35, 'retrieval', 'START RETRIEVAL')
# (Partially) matching chunk: proposition(derived= yes, element= a, form= a:A&/Es.F, inferred1= none, inferred2= yes, mainconnective= conjunction, relation= none, subformula1= a:A, subformula2= a:/Es.F, thing= proposition)
# Base level learning: 0.0
# Spreading activation 0
# Partial matching 0
# Noise: 0
# Total activation 0.0
# Time to retrieve 0.1
# (1.35, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (1.35, 'PROCEDURAL', 'NO RULE FOUND')
# (1.45, 'retrieval', 'CLEARED')
# (1.45, 'retrieval', 'RETRIEVED: proposition(derived= yes, element= a, form= a:A&/Es.F, inferred1= none, inferred2= yes, mainconnective= conjunction, relation= none, subformula1= a:A, subformula2= a:/Es.F, thing= proposition)')
# (1.45, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (1.45, 'PROCEDURAL', 'RULE SELECTED: first_conjunct_inferred_a')
# (1.5, 'PROCEDURAL', 'RULE CREATED: find formula to apply rule to and conjunction found, second conjunct inferred? 1 and conjunction found, second conjunct inferred? 2')
# (1.5, 'PROCEDURAL', 'RULE FIRED: first_conjunct_inferred_a')
# (1.5, 'g', 'MODIFIED')
# (1.5, 'retrieval', 'CLEARED')
# (1.5, 'imaginal', 'CLEARED')
# (1.5, 'imaginal', 'CREATED A CHUNK: proposition(derived= yes, element= a, form= a:A&/Es.F, inferred1= none, inferred2= yes, mainconnective= conjunction, relation= none, subformula1= a:A, subformula2= a:/Es.F, thing= proposition)')
# (1.5, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (1.5, 'PROCEDURAL', 'RULE SELECTED: first_conjunct_inferred_b')
# (1.55, 'PROCEDURAL', 'RULE CREATED: conjunction found, second conjunct inferred? 2 and first_conjunct_inferred_a')
# (1.55, 'PROCEDURAL', 'RULE FIRED: first_conjunct_inferred_b')
# (1.55, 'g', 'MODIFIED')
# (1.55, 'imaginal', 'MODIFIED')
# (1.55, 'retrieval', 'START RETRIEVAL')
# (1.55, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (1.55, 'PROCEDURAL', 'NO RULE FOUND')
# (1.65, 'retrieval', 'RETRIEVED: None')
# (1.65, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (1.65, 'PROCEDURAL', 'RULE SELECTED: label first conjunct as inferred after second')
# (1.7, 'PROCEDURAL', 'RULE CREATED: first_conjunct_inferred_a and first_conjunct_inferred_b')
# (1.7, 'PROCEDURAL', 'RULE FIRED: label first conjunct as inferred after second')
# (1.7, 'g', 'MODIFIED')
# (1.7, 'retrieval', 'CLEARED')
# (1.7, 'imaginal', 'CLEARED')
# (1.7, 'imaginal', 'CREATED A CHUNK: proposition(derived= yes, element= a, form= a:A&/Es.F, inferred1= yes, inferred2= yes, mainconnective= conjunction, relation= none, subformula1= a:A, subformula2= a:/Es.F, thing= proposition)')
# (1.7, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (1.7, 'PROCEDURAL', 'RULE SELECTED: retrieve first conjunct after second')
# (1.75, 'PROCEDURAL', 'RULE FIRED: retrieve first conjunct after second')
# (1.75, 'g', 'MODIFIED')
# (1.75, 'retrieval', 'START RETRIEVAL')
# (Partially) matching chunk: proposition(derived= no, element= a, form= a:A, inferred1= , inferred2= , mainconnective= concept, relation= , subformula1= A, subformula2= , thing= proposition)
# Base level learning: 0.0
# Spreading activation 0
# Partial matching 0
# Noise: 0
# Total activation 0.0
# Time to retrieve 0.1
# (1.75, 'imaginal', 'CLEARED')
# (1.75, 'imaginal', 'CREATED A CHUNK: proposition(derived= yes, element= a, form= a:A&/Es.F, inferred1= yes, inferred2= yes, mainconnective= conjunction, relation= none, subformula1= a:A, subformula2= a:/Es.F, thing= proposition)')
# (1.75, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (1.75, 'PROCEDURAL', 'NO RULE FOUND')
# (1.85, 'retrieval', 'CLEARED')
# (1.85, 'retrieval', 'RETRIEVED: proposition(derived= no, element= a, form= a:A, inferred1= , inferred2= , mainconnective= concept, relation= , subformula1= A, subformula2= , thing= proposition)')
# (1.85, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (1.85, 'PROCEDURAL', 'RULE SELECTED: label first conjunct as derived after second')
# (1.9, 'PROCEDURAL', 'RULE FIRED: label first conjunct as derived after second')
# (1.9, 'g', 'MODIFIED')
# (1.9, 'imaginal', 'CLEARED')
# (1.9, 'imaginal', 'CREATED A CHUNK: proposition(derived= yes, element= a, form= a:A, inferred1= None, inferred2= None, mainconnective= concept, relation= None, subformula1= A, subformula2= None, thing= proposition)')
# (1.9, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (1.9, 'PROCEDURAL', 'RULE SELECTED: do we need to check for a clash? concept found')
# (1.95, 'PROCEDURAL', 'RULE FIRED: do we need to check for a clash? concept found')
# (1.95, 'g', 'MODIFIED')
# (1.95, 'retrieval', 'CLEARED')
# (1.95, 'imaginal', 'CLEARED')
# (1.95, 'imaginal', 'CREATED A CHUNK: checklist(element= a, form2= none, form3= none, form4= none, form5= none, form6= none, form7= none, form8= none, form= a:A, mainconnective= concept, relation= none, subformula1= A, subformula2= none, thing= checklist)')
# (1.95, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (1.95, 'PROCEDURAL', 'RULE SELECTED: find clash 1')
# (2.0, 'PROCEDURAL', 'RULE FIRED: find clash 1')
# (2.0, 'g', 'MODIFIED')
# (2.0, 'imaginal', 'CLEARED')
# (2.0, 'retrieval', 'START RETRIEVAL')
# (2.0, 'imaginal', 'CREATED A CHUNK: checklist(element= a, form2= none, form3= none, form4= none, form5= none, form6= none, form7= none, form8= , form= a:A, mainconnective= concept, relation= none, subformula1= A, subformula2= , thing= checklist)')
# (2.0, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (2.0, 'PROCEDURAL', 'NO RULE FOUND')
# (2.1, 'retrieval', 'RETRIEVED: None')
# (2.1, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (2.1, 'PROCEDURAL', 'RULE SELECTED: no clash 1')
# (2.15, 'PROCEDURAL', 'RULE FIRED: no clash 1')
# (2.15, 'g', 'MODIFIED')
# (2.15, 'retrieval', 'CLEARED')
# (2.15, 'imaginal', 'CLEARED')
# (2.15, 'imaginal', 'CREATED A CHUNK: checklist(element= none, form2= a:A, form3= none, form4= none, form5= none, form6= none, form7= none, form8= none, form= none, mainconnective= none, relation= none, subformula1= none, subformula2= none, thing= checklist)')
# (2.15, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (2.15, 'PROCEDURAL', 'RULE SELECTED: find next formula')
# (2.2, 'PROCEDURAL', 'RULE FIRED: find next formula')
# (2.2, 'g', 'MODIFIED')
# (2.2, 'imaginal', 'MODIFIED')
# (2.2, 'retrieval', 'START RETRIEVAL')
# (Partially) matching chunk: proposition(derived= yes, element= b, form= b:B, inferred1= , inferred2= , mainconnective= concept, relation= , subformula1= B, subformula2= , thing= proposition)
# Base level learning: 0.6931471805599453
# Spreading activation 0
# Partial matching 0
# Noise: 0
# Total activation 0.6931471805599453
# Time to retrieve 0.05
# (2.2, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (2.2, 'PROCEDURAL', 'NO RULE FOUND')
# (2.25, 'retrieval', 'CLEARED')
# (2.25, 'retrieval', 'RETRIEVED: proposition(derived= yes, element= b, form= b:B, inferred1= , inferred2= , mainconnective= concept, relation= , subformula1= B, subformula2= , thing= proposition)')
# (2.25, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (2.25, 'PROCEDURAL', 'RULE SELECTED: repeat')
# (2.3, 'PROCEDURAL', 'RULE RE-CREATED: no clash 1 and find next formula')
# (2.3, 'PROCEDURAL', 'RULE FIRED: repeat')
# (2.3, 'g', 'MODIFIED')
# (2.3, 'retrieval', 'CLEARED')
# (2.3, 'imaginal', 'CLEARED')
# (2.3, 'imaginal', 'CREATED A CHUNK: checklist(element= b, form2= a:A, form3= none, form4= none, form5= none, form6= none, form7= none, form8= none, form= b:B, mainconnective= concept, relation= none, subformula1= B, subformula2= none, thing= checklist)')
# (2.3, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (2.3, 'PROCEDURAL', 'RULE SELECTED: find clash 1')
# (2.35, 'PROCEDURAL', 'RULE CREATED: find next formula and repeat')
# (2.35, 'PROCEDURAL', 'RULE FIRED: find clash 1')
# (2.35, 'g', 'MODIFIED')
# (2.35, 'imaginal', 'CLEARED')
# (2.35, 'retrieval', 'START RETRIEVAL')
# (2.35, 'imaginal', 'CREATED A CHUNK: checklist(element= b, form2= a:A, form3= none, form4= none, form5= none, form6= none, form7= none, form8= , form= b:B, mainconnective= concept, relation= none, subformula1= B, subformula2= , thing= checklist)')
# (2.35, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (2.35, 'PROCEDURAL', 'NO RULE FOUND')
# (2.45, 'retrieval', 'RETRIEVED: None')
# (2.45, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (2.45, 'PROCEDURAL', 'RULE SELECTED: no clash 1')
# (2.5, 'PROCEDURAL', 'RULE FIRED: no clash 1')
# (2.5, 'g', 'MODIFIED')
# (2.5, 'retrieval', 'CLEARED')
# (2.5, 'imaginal', 'CLEARED')
# (2.5, 'imaginal', 'CREATED A CHUNK: checklist(element= none, form2= b:B, form3= a:A, form4= none, form5= none, form6= none, form7= none, form8= none, form= none, mainconnective= none, relation= none, subformula1= none, subformula2= none, thing= checklist)')
# (2.5, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (2.5, 'PROCEDURAL', 'RULE SELECTED: find next formula')
# (2.55, 'PROCEDURAL', 'RULE FIRED: find next formula')
# (2.55, 'g', 'MODIFIED')
# (2.55, 'imaginal', 'MODIFIED')
# (2.55, 'retrieval', 'START RETRIEVAL')
# (2.55, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (2.55, 'PROCEDURAL', 'NO RULE FOUND')
# (2.65, 'retrieval', 'RETRIEVED: None')
# (2.65, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (2.65, 'PROCEDURAL', 'RULE SELECTED: move on')
# (2.7, 'PROCEDURAL', 'RULE RE-CREATED: no clash 1 and find next formula')
# (2.7, 'PROCEDURAL', 'RULE FIRED: move on')
# (2.7, 'g', 'MODIFIED')
# (2.7, 'retrieval', 'CLEARED')
# (2.7, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (2.7, 'PROCEDURAL', 'RULE SELECTED: find formula to apply rule to and conjunction found, second conjunct inferred? 1')
# (2.75, 'PROCEDURAL', 'RULE FIRED: find formula to apply rule to and conjunction found, second conjunct inferred? 1')
# (2.75, 'g', 'MODIFIED')
# (2.75, 'retrieval', 'CLEARED')
# (2.75, 'imaginal', 'CLEARED')
# (2.75, 'imaginal', 'CREATED A CHUNK: proposition(derived= yes, element= a, form= a:A&/Es.F, inferred1= no, inferred2= no, mainconnective= conjunction, relation= none, subformula1= a:A, subformula2= a:/Es.F, thing= proposition)')
# (2.75, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (2.75, 'PROCEDURAL', 'RULE SELECTED: conjunction found, second conjunct inferred? 2')
# (2.8, 'PROCEDURAL', 'RULE CREATED: move on and find formula to apply rule to and conjunction found, second conjunct inferred? 1')
# (2.8, 'PROCEDURAL', 'RULE FIRED: conjunction found, second conjunct inferred? 2')
# (2.8, 'g', 'MODIFIED')
# (2.8, 'imaginal', 'MODIFIED')
# (2.8, 'retrieval', 'START RETRIEVAL')
# (Partially) matching chunk: proposition(derived= yes, element= a, form= a:A&/Es.F, inferred1= none, inferred2= yes, mainconnective= conjunction, relation= none, subformula1= a:A, subformula2= a:/Es.F, thing= proposition)
# Base level learning: 1.0986122886681098
# Spreading activation 0
# Partial matching 0
# Noise: 0
# Total activation 1.0986122886681098
# Time to retrieve 0.03333333333333333
# (2.8, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (2.8, 'PROCEDURAL', 'NO RULE FOUND')
# (2.8333, 'retrieval', 'CLEARED')
# (2.8333, 'retrieval', 'RETRIEVED: proposition(derived= yes, element= a, form= a:A&/Es.F, inferred1= none, inferred2= yes, mainconnective= conjunction, relation= none, subformula1= a:A, subformula2= a:/Es.F, thing= proposition)')
# (2.8333, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (2.8333, 'PROCEDURAL', 'RULE SELECTED: first_conjunct_inferred_a')
# (2.8833, 'PROCEDURAL', 'RULE RE-CREATED: find formula to apply rule to and conjunction found, second conjunct inferred? 1 and conjunction found, second conjunct inferred? 2')
# (2.8833, 'PROCEDURAL', 'RULE FIRED: first_conjunct_inferred_a')
# (2.8833, 'g', 'MODIFIED')
# (2.8833, 'retrieval', 'CLEARED')
# (2.8833, 'imaginal', 'CLEARED')
# (2.8833, 'imaginal', 'CREATED A CHUNK: proposition(derived= yes, element= a, form= a:A&/Es.F, inferred1= none, inferred2= yes, mainconnective= conjunction, relation= none, subformula1= a:A, subformula2= a:/Es.F, thing= proposition)')
# (2.8833, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (2.8833, 'PROCEDURAL', 'RULE SELECTED: first_conjunct_inferred_b')
# (2.9333, 'PROCEDURAL', 'RULE RE-CREATED: conjunction found, second conjunct inferred? 2 and first_conjunct_inferred_a')
# (2.9333, 'PROCEDURAL', 'RULE FIRED: first_conjunct_inferred_b')
# (2.9333, 'g', 'MODIFIED')
# (2.9333, 'imaginal', 'MODIFIED')
# (2.9333, 'retrieval', 'START RETRIEVAL')
# (Partially) matching chunk: proposition(derived= yes, element= a, form= a:A&/Es.F, inferred1= yes, inferred2= yes, mainconnective= conjunction, relation= none, subformula1= a:A, subformula2= a:/Es.F, thing= proposition)
# Base level learning: 0.6931471805599453
# Spreading activation 0
# Partial matching 0
# Noise: 0
# Total activation 0.6931471805599453
# Time to retrieve 0.05
# (2.9333, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (2.9333, 'PROCEDURAL', 'NO RULE FOUND')
# (2.9833, 'retrieval', 'CLEARED')
# (2.9833, 'retrieval', 'RETRIEVED: proposition(derived= yes, element= a, form= a:A&/Es.F, inferred1= yes, inferred2= yes, mainconnective= conjunction, relation= none, subformula1= a:A, subformula2= a:/Es.F, thing= proposition)')
# (2.9833, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (2.9833, 'PROCEDURAL', 'RULE SELECTED: store in list 2')
# (3.0333, 'PROCEDURAL', 'RULE RE-CREATED: first_conjunct_inferred_a and first_conjunct_inferred_b')
# (3.0333, 'PROCEDURAL', 'RULE FIRED: store in list 2')
# (3.0333, 'g', 'MODIFIED')
# (3.0333, 'imaginal', 'CLEARED')
# (3.0333, 'imaginal', 'CREATED A CHUNK: storelist(derived= none, element= a, form10= none, form11= none, form12= none, form13= none, form14= none, form15= none, form2= none, form3= none, form4= none, form5= none, form6= none, form7= none, form8= none, form9= none, form= a:A&/Es.F, inferred1= none, inferred2= none, mainconnective= conjunction, relation= none, subformula1= a:A, subformula2= a:/Es.F, thing= storelist)')
# (3.0333, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (3.0333, 'PROCEDURAL', 'RULE SELECTED: retrieve the next proposition to store in the list')
# (3.0833, 'PROCEDURAL', 'RULE FIRED: retrieve the next proposition to store in the list')
# (3.0833, 'g', 'MODIFIED')
# (3.0833, 'retrieval', 'START RETRIEVAL')
# (3.0833, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (3.0833, 'PROCEDURAL', 'NO RULE FOUND')
# (3.1833, 'retrieval', 'RETRIEVED: None')
# (3.1833, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (3.1833, 'PROCEDURAL', 'RULE SELECTED: use the list to select the next formula')
# (3.2333, 'PROCEDURAL', 'RULE CREATED: store in list 2 and retrieve the next proposition to store in the list')
# (3.2333, 'PROCEDURAL', 'RULE FIRED: use the list to select the next formula')
# (3.2333, 'g', 'MODIFIED')
# (3.2333, 'retrieval', 'START RETRIEVAL')
# (Partially) matching chunk: proposition(derived= yes, element= c, form= c:C&/Es.D, inferred1= no, inferred2= no, mainconnective= conjunction, relation= , subformula1= c:C, subformula2= c:/Es.D, thing= proposition)
# Base level learning: 0.0
# Spreading activation 0
# Partial matching 0
# Noise: 0
# Total activation 0.0
# Time to retrieve 0.1
# (3.2333, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (3.2333, 'PROCEDURAL', 'NO RULE FOUND')
# (3.3333, 'retrieval', 'CLEARED')
# (3.3333, 'retrieval', 'RETRIEVED: proposition(derived= yes, element= c, form= c:C&/Es.D, inferred1= no, inferred2= no, mainconnective= conjunction, relation= , subformula1= c:C, subformula2= c:/Es.D, thing= proposition)')
# (3.3333, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (3.3333, 'PROCEDURAL', 'RULE SELECTED: conjunction found, first conjunct inferred? 1')
# (3.3833, 'PROCEDURAL', 'RULE FIRED: conjunction found, first conjunct inferred? 1')
# (3.3833, 'g', 'MODIFIED')
# (3.3833, 'retrieval', 'CLEARED')
# (3.3833, 'imaginal', 'CLEARED')
# (3.3833, 'imaginal', 'CREATED A CHUNK: proposition(derived= yes, element= c, form= c:C&/Es.D, inferred1= no, inferred2= no, mainconnective= conjunction, relation= none, subformula1= c:C, subformula2= c:/Es.D, thing= proposition)')
# (3.3833, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (3.3833, 'PROCEDURAL', 'RULE SELECTED: conjunction found, first conjunct inferred? 2')
# (3.4333, 'PROCEDURAL', 'RULE CREATED: use the list to select the next formula and conjunction found, first conjunct inferred? 1')
# (3.4333, 'PROCEDURAL', 'RULE FIRED: conjunction found, first conjunct inferred? 2')
# (3.4333, 'g', 'MODIFIED')
# (3.4333, 'imaginal', 'MODIFIED')
# (3.4333, 'retrieval', 'START RETRIEVAL')
# (3.4333, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (3.4333, 'PROCEDURAL', 'NO RULE FOUND')
# (3.5333, 'retrieval', 'RETRIEVED: None')
# (3.5333, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (3.5333, 'PROCEDURAL', 'RULE SELECTED: label first conjunct as inferred')
# (3.5833, 'PROCEDURAL', 'RULE CREATED: conjunction found, first conjunct inferred? 1 and conjunction found, first conjunct inferred? 2')
# (3.5833, 'PROCEDURAL', 'RULE FIRED: label first conjunct as inferred')
# (3.5833, 'g', 'MODIFIED')
# (3.5833, 'retrieval', 'CLEARED')
# (3.5833, 'imaginal', 'CLEARED')
# (3.5833, 'imaginal', 'CREATED A CHUNK: proposition(derived= yes, element= c, form= c:C&/Es.D, inferred1= yes, inferred2= none, mainconnective= conjunction, relation= none, subformula1= c:C, subformula2= c:/Es.D, thing= proposition)')
# (3.5833, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (3.5833, 'PROCEDURAL', 'RULE SELECTED: retrieve first conjunct')
# (3.6333, 'PROCEDURAL', 'RULE FIRED: retrieve first conjunct')
# (3.6333, 'g', 'MODIFIED')
# (3.6333, 'imaginal', 'CLEARED')
# (3.6333, 'retrieval', 'START RETRIEVAL')
# (Partially) matching chunk: proposition(derived= no, element= c, form= c:C, inferred1= , inferred2= , mainconnective= concept, relation= , subformula1= C, subformula2= , thing= proposition)
# Base level learning: 0.0
# Spreading activation 0
# Partial matching 0
# Noise: 0
# Total activation 0.0
# Time to retrieve 0.1
# (3.6333, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (3.6333, 'PROCEDURAL', 'NO RULE FOUND')
# (3.7333, 'retrieval', 'CLEARED')
# (3.7333, 'retrieval', 'RETRIEVED: proposition(derived= no, element= c, form= c:C, inferred1= , inferred2= , mainconnective= concept, relation= , subformula1= C, subformula2= , thing= proposition)')
# (3.7333, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (3.7333, 'PROCEDURAL', 'RULE SELECTED: label first conjunct as derived')
# (3.7833, 'PROCEDURAL', 'RULE CREATED: label first conjunct as inferred and retrieve first conjunct')
# (3.7833, 'PROCEDURAL', 'RULE FIRED: label first conjunct as derived')
# (3.7833, 'g', 'MODIFIED')
# (3.7833, 'imaginal', 'CLEARED')
# (3.7833, 'imaginal', 'CREATED A CHUNK: proposition(derived= yes, element= c, form= c:C, inferred1= none, inferred2= none, mainconnective= concept, relation= none, subformula1= C, subformula2= None, thing= proposition)')
# (3.7833, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (3.7833, 'PROCEDURAL', 'RULE SELECTED: do we need to check for a clash? concept found')
# (3.8333, 'PROCEDURAL', 'RULE FIRED: do we need to check for a clash? concept found')
# (3.8333, 'g', 'MODIFIED')
# (3.8333, 'retrieval', 'CLEARED')
# (3.8333, 'imaginal', 'CLEARED')
# (3.8333, 'imaginal', 'CREATED A CHUNK: checklist(element= c, form2= none, form3= none, form4= none, form5= none, form6= none, form7= none, form8= none, form= c:C, mainconnective= concept, relation= none, subformula1= C, subformula2= none, thing= checklist)')
# (3.8333, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (3.8333, 'PROCEDURAL', 'RULE SELECTED: find clash 1')
# (3.8833, 'PROCEDURAL', 'RULE FIRED: find clash 1')
# (3.8833, 'g', 'MODIFIED')
# (3.8833, 'imaginal', 'CLEARED')
# (3.8833, 'retrieval', 'START RETRIEVAL')
# (3.8833, 'imaginal', 'CREATED A CHUNK: checklist(element= c, form2= none, form3= none, form4= none, form5= none, form6= none, form7= none, form8= , form= c:C, mainconnective= concept, relation= none, subformula1= C, subformula2= , thing= checklist)')
# (3.8833, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (3.8833, 'PROCEDURAL', 'NO RULE FOUND')
# (3.9833, 'retrieval', 'RETRIEVED: None')
# (3.9833, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (3.9833, 'PROCEDURAL', 'RULE SELECTED: no clash 1 and find next formula')
# (4.0333, 'PROCEDURAL', 'RULE FIRED: no clash 1 and find next formula')
# (4.0333, 'g', 'MODIFIED')
# (4.0333, 'imaginal', 'MODIFIED')
# (4.0333, 'retrieval', 'START RETRIEVAL')
# (Partially) matching chunk: proposition(derived= yes, element= b, form= b:B, inferred1= , inferred2= , mainconnective= concept, relation= , subformula1= B, subformula2= , thing= proposition)
# Base level learning: 1.0986122886681098
# Spreading activation 0
# Partial matching 0
# Noise: 0
# Total activation 1.0986122886681098
# Time to retrieve 0.03333333333333333
# (4.0333, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (4.0333, 'PROCEDURAL', 'NO RULE FOUND')
# (4.0666, 'retrieval', 'CLEARED')
# (4.0666, 'retrieval', 'RETRIEVED: proposition(derived= yes, element= b, form= b:B, inferred1= , inferred2= , mainconnective= concept, relation= , subformula1= B, subformula2= , thing= proposition)')
# (4.0666, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (4.0666, 'PROCEDURAL', 'RULE SELECTED: repeat')
# (4.1166, 'PROCEDURAL', 'RULE FIRED: repeat')
# (4.1166, 'g', 'MODIFIED')
# (4.1166, 'retrieval', 'CLEARED')
# (4.1166, 'imaginal', 'CLEARED')
# (4.1166, 'imaginal', 'CREATED A CHUNK: checklist(element= b, form2= c:C, form3= none, form4= none, form5= none, form6= none, form7= none, form8= none, form= b:B, mainconnective= concept, relation= none, subformula1= B, subformula2= none, thing= checklist)')
# (4.1166, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (4.1166, 'PROCEDURAL', 'RULE SELECTED: find clash 1')
# (4.1666, 'PROCEDURAL', 'RULE CREATED: no clash 1 and find next formula and repeat')
# (4.1666, 'PROCEDURAL', 'RULE FIRED: find clash 1')
# (4.1666, 'g', 'MODIFIED')
# (4.1666, 'imaginal', 'CLEARED')
# (4.1666, 'retrieval', 'START RETRIEVAL')
# (4.1666, 'imaginal', 'CREATED A CHUNK: checklist(element= b, form2= c:C, form3= none, form4= none, form5= none, form6= none, form7= none, form8= , form= b:B, mainconnective= concept, relation= none, subformula1= B, subformula2= , thing= checklist)')
# (4.1666, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (4.1666, 'PROCEDURAL', 'NO RULE FOUND')
# (4.2666, 'retrieval', 'RETRIEVED: None')
# (4.2666, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (4.2666, 'PROCEDURAL', 'RULE SELECTED: no clash 1')
# (4.3166, 'PROCEDURAL', 'RULE FIRED: no clash 1')
# (4.3166, 'g', 'MODIFIED')
# (4.3166, 'retrieval', 'CLEARED')
# (4.3166, 'imaginal', 'CLEARED')
# (4.3166, 'imaginal', 'CREATED A CHUNK: checklist(element= none, form2= b:B, form3= c:C, form4= none, form5= none, form6= none, form7= none, form8= none, form= none, mainconnective= none, relation= none, subformula1= none, subformula2= none, thing= checklist)')
# (4.3166, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (4.3166, 'PROCEDURAL', 'RULE SELECTED: find next formula and repeat')
# (4.3666, 'PROCEDURAL', 'RULE FIRED: find next formula and repeat')
# (4.3666, 'g', 'MODIFIED')
# (4.3666, 'retrieval', 'CLEARED')
# (4.3666, 'imaginal', 'CLEARED')
# (4.3666, 'imaginal', 'CREATED A CHUNK: checklist(element= b, form2= b:B, form3= c:C, form4= none, form5= none, form6= none, form7= none, form8= none, form= b:B, mainconnective= concept, relation= none, subformula1= B, subformula2= none, thing= checklist)')
# (4.3666, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (4.3666, 'PROCEDURAL', 'RULE SELECTED: find clash 1')
# (4.4166, 'PROCEDURAL', 'RULE FIRED: find clash 1')
# (4.4166, 'g', 'MODIFIED')
# (4.4166, 'imaginal', 'CLEARED')
# (4.4166, 'retrieval', 'START RETRIEVAL')
# (4.4166, 'imaginal', 'CREATED A CHUNK: checklist(element= b, form2= b:B, form3= c:C, form4= none, form5= none, form6= none, form7= none, form8= , form= b:B, mainconnective= concept, relation= none, subformula1= B, subformula2= , thing= checklist)')
# (4.4166, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (4.4166, 'PROCEDURAL', 'NO RULE FOUND')
# (4.5166, 'retrieval', 'RETRIEVED: None')
# (4.5166, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (4.5166, 'PROCEDURAL', 'RULE SELECTED: no clash 1 and find next formula')
# (4.5666, 'PROCEDURAL', 'RULE FIRED: no clash 1 and find next formula')
# (4.5666, 'g', 'MODIFIED')
# (4.5666, 'imaginal', 'MODIFIED')
# (4.5666, 'retrieval', 'START RETRIEVAL')
# (Partially) matching chunk: proposition(derived= yes, element= a, form= a:A, inferred1= None, inferred2= None, mainconnective= concept, relation= None, subformula1= A, subformula2= None, thing= proposition)
# Base level learning: 0.0
# Spreading activation 0
# Partial matching 0
# Noise: 0
# Total activation 0.0
# Time to retrieve 0.1
# (4.5666, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (4.5666, 'PROCEDURAL', 'NO RULE FOUND')
# (4.6666, 'retrieval', 'CLEARED')
# (4.6666, 'retrieval', 'RETRIEVED: proposition(derived= yes, element= a, form= a:A, inferred1= None, inferred2= None, mainconnective= concept, relation= None, subformula1= A, subformula2= None, thing= proposition)')
# (4.6666, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (4.6666, 'PROCEDURAL', 'RULE SELECTED: repeat')
# (4.7166, 'PROCEDURAL', 'RULE FIRED: repeat')
# (4.7166, 'g', 'MODIFIED')
# (4.7166, 'retrieval', 'CLEARED')
# (4.7166, 'imaginal', 'CLEARED')
# (4.7166, 'imaginal', 'CREATED A CHUNK: checklist(element= a, form2= b:B, form3= b:B, form4= c:C, form5= none, form6= none, form7= none, form8= none, form= a:A, mainconnective= concept, relation= none, subformula1= A, subformula2= none, thing= checklist)')
# (4.7166, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (4.7166, 'PROCEDURAL', 'RULE SELECTED: find clash 1')
# (4.7666, 'PROCEDURAL', 'RULE CREATED: no clash 1 and find next formula and repeat 1')
# (4.7666, 'PROCEDURAL', 'RULE FIRED: find clash 1')
# (4.7666, 'g', 'MODIFIED')
# (4.7666, 'imaginal', 'CLEARED')
# (4.7666, 'retrieval', 'START RETRIEVAL')
# (4.7666, 'imaginal', 'CREATED A CHUNK: checklist(element= a, form2= b:B, form3= b:B, form4= c:C, form5= none, form6= none, form7= none, form8= , form= a:A, mainconnective= concept, relation= none, subformula1= A, subformula2= , thing= checklist)')
# (4.7666, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (4.7666, 'PROCEDURAL', 'NO RULE FOUND')
# (4.8666, 'retrieval', 'RETRIEVED: None')
# (4.8666, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (4.8666, 'PROCEDURAL', 'RULE SELECTED: no clash 1')
# (4.9166, 'PROCEDURAL', 'RULE FIRED: no clash 1')
# (4.9166, 'g', 'MODIFIED')
# (4.9166, 'retrieval', 'CLEARED')
# (4.9166, 'imaginal', 'CLEARED')
# (4.9166, 'imaginal', 'CREATED A CHUNK: checklist(element= none, form2= a:A, form3= b:B, form4= b:B, form5= c:C, form6= none, form7= none, form8= none, form= none, mainconnective= none, relation= none, subformula1= none, subformula2= none, thing= checklist)')
# (4.9166, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (4.9166, 'PROCEDURAL', 'RULE SELECTED: find next formula')
# (4.9666, 'PROCEDURAL', 'RULE FIRED: find next formula')
# (4.9666, 'g', 'MODIFIED')
# (4.9666, 'imaginal', 'MODIFIED')
# (4.9666, 'retrieval', 'START RETRIEVAL')
# (4.9666, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (4.9666, 'PROCEDURAL', 'NO RULE FOUND')
# (5.0666, 'retrieval', 'RETRIEVED: None')
# (5.0666, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (5.0666, 'PROCEDURAL', 'RULE SELECTED: move on and find formula to apply rule to and conjunction found, second conjunct inferred? 1')
# (5.1166, 'PROCEDURAL', 'RULE RE-CREATED: no clash 1 and find next formula')
# (5.1166, 'PROCEDURAL', 'RULE FIRED: move on and find formula to apply rule to and conjunction found, second conjunct inferred? 1')
# (5.1166, 'g', 'MODIFIED')
# (5.1166, 'retrieval', 'CLEARED')
# (5.1166, 'imaginal', 'CLEARED')
# (5.1166, 'imaginal', 'CREATED A CHUNK: proposition(derived= yes, element= a, form= a:A&/Es.F, inferred1= no, inferred2= no, mainconnective= conjunction, relation= none, subformula1= a:A, subformula2= a:/Es.F, thing= proposition)')
# (5.1166, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (5.1166, 'PROCEDURAL', 'RULE SELECTED: conjunction found, second conjunct inferred? 2 and first_conjunct_inferred_a')
# (5.1666, 'PROCEDURAL', 'RULE FIRED: conjunction found, second conjunct inferred? 2 and first_conjunct_inferred_a')
# (5.1666, 'g', 'MODIFIED')
# (5.1666, 'retrieval', 'CLEARED')
# (5.1666, 'imaginal', 'CLEARED')
# (5.1666, 'imaginal', 'CREATED A CHUNK: proposition(derived= yes, element= a, form= a:A&/Es.F, inferred1= none, inferred2= yes, mainconnective= conjunction, relation= none, subformula1= a:A, subformula2= a:/Es.F, thing= proposition)')
# (5.1666, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (5.1666, 'PROCEDURAL', 'RULE SELECTED: first_conjunct_inferred_b')
# (5.2166, 'PROCEDURAL', 'RULE FIRED: first_conjunct_inferred_b')
# (5.2166, 'g', 'MODIFIED')
# (5.2166, 'imaginal', 'MODIFIED')
# (5.2166, 'retrieval', 'START RETRIEVAL')
# (Partially) matching chunk: proposition(derived= yes, element= a, form= a:A&/Es.F, inferred1= yes, inferred2= yes, mainconnective= conjunction, relation= none, subformula1= a:A, subformula2= a:/Es.F, thing= proposition)
# Base level learning: 1.0986122886681098
# Spreading activation 0
# Partial matching 0
# Noise: 0
# Total activation 1.0986122886681098
# Time to retrieve 0.03333333333333333
# (5.2166, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (5.2166, 'PROCEDURAL', 'NO RULE FOUND')
# (5.2499, 'retrieval', 'CLEARED')
# (5.2499, 'retrieval', 'RETRIEVED: proposition(derived= yes, element= a, form= a:A&/Es.F, inferred1= yes, inferred2= yes, mainconnective= conjunction, relation= none, subformula1= a:A, subformula2= a:/Es.F, thing= proposition)')
# (5.2499, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (5.2499, 'PROCEDURAL', 'RULE SELECTED: store in list 2')
# (5.2999, 'PROCEDURAL', 'RULE CREATED: conjunction found, second conjunct inferred? 2 and first_conjunct_inferred_a and first_conjunct_inferred_b')
# (5.2999, 'PROCEDURAL', 'RULE FIRED: store in list 2')
# (5.2999, 'g', 'MODIFIED')
# (5.2999, 'imaginal', 'CLEARED')
# (5.2999, 'imaginal', 'CREATED A CHUNK: storelist(derived= none, element= a, form10= none, form11= none, form12= none, form13= none, form14= none, form15= none, form2= none, form3= none, form4= none, form5= none, form6= none, form7= none, form8= none, form9= none, form= a:A&/Es.F, inferred1= none, inferred2= none, mainconnective= conjunction, relation= none, subformula1= a:A, subformula2= a:/Es.F, thing= storelist)')
# (5.2999, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (5.2999, 'PROCEDURAL', 'RULE SELECTED: retrieve the next proposition to store in the list')
# (5.3499, 'PROCEDURAL', 'RULE FIRED: retrieve the next proposition to store in the list')
# (5.3499, 'g', 'MODIFIED')
# (5.3499, 'retrieval', 'START RETRIEVAL')
# (5.3499, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (5.3499, 'PROCEDURAL', 'NO RULE FOUND')
# (5.4499, 'retrieval', 'RETRIEVED: None')
# (5.4499, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (5.4499, 'PROCEDURAL', 'RULE SELECTED: use the list to select the next formula')
# (5.4999, 'PROCEDURAL', 'RULE RE-CREATED: store in list 2 and retrieve the next proposition to store in the list')
# (5.4999, 'PROCEDURAL', 'RULE FIRED: use the list to select the next formula')
# (5.4999, 'g', 'MODIFIED')
# (5.4999, 'retrieval', 'START RETRIEVAL')
# (Partially) matching chunk: proposition(derived= yes, element= c, form= c:C&/Es.D, inferred1= no, inferred2= no, mainconnective= conjunction, relation= , subformula1= c:C, subformula2= c:/Es.D, thing= proposition)
# Base level learning: 0.6931471805599453
# Spreading activation 0
# Partial matching 0
# Noise: 0
# Total activation 0.6931471805599453
# Time to retrieve 0.05
# (5.4999, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (5.4999, 'PROCEDURAL', 'NO RULE FOUND')
# (5.5499, 'retrieval', 'CLEARED')
# (5.5499, 'retrieval', 'RETRIEVED: proposition(derived= yes, element= c, form= c:C&/Es.D, inferred1= no, inferred2= no, mainconnective= conjunction, relation= , subformula1= c:C, subformula2= c:/Es.D, thing= proposition)')
# (5.5499, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (5.5499, 'PROCEDURAL', 'RULE SELECTED: conjunction found, second conjunct inferred? 1')
# (5.5999, 'PROCEDURAL', 'RULE FIRED: conjunction found, second conjunct inferred? 1')
# (5.5999, 'g', 'MODIFIED')
# (5.5999, 'retrieval', 'CLEARED')
# (5.5999, 'imaginal', 'CLEARED')
# (5.5999, 'imaginal', 'CREATED A CHUNK: proposition(derived= yes, element= c, form= c:C&/Es.D, inferred1= no, inferred2= no, mainconnective= conjunction, relation= none, subformula1= c:C, subformula2= c:/Es.D, thing= proposition)')
# (5.5999, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (5.5999, 'PROCEDURAL', 'RULE SELECTED: conjunction found, second conjunct inferred? 2')
# (5.6499, 'PROCEDURAL', 'RULE CREATED: use the list to select the next formula and conjunction found, second conjunct inferred? 1')
# (5.6499, 'PROCEDURAL', 'RULE FIRED: conjunction found, second conjunct inferred? 2')
# (5.6499, 'g', 'MODIFIED')
# (5.6499, 'imaginal', 'MODIFIED')
# (5.6499, 'retrieval', 'START RETRIEVAL')
# (5.6499, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (5.6499, 'PROCEDURAL', 'NO RULE FOUND')
# (5.7499, 'retrieval', 'RETRIEVED: None')
# (5.7499, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (5.7499, 'PROCEDURAL', 'RULE SELECTED: label second conjunct as inferred')
# (5.7999, 'PROCEDURAL', 'RULE RE-CREATED: conjunction found, second conjunct inferred? 1 and conjunction found, second conjunct inferred? 2')
# (5.7999, 'PROCEDURAL', 'RULE FIRED: label second conjunct as inferred')
# (5.7999, 'g', 'MODIFIED')
# (5.7999, 'retrieval', 'CLEARED')
# (5.7999, 'imaginal', 'CLEARED')
# (5.7999, 'imaginal', 'CREATED A CHUNK: proposition(derived= yes, element= c, form= c:C&/Es.D, inferred1= none, inferred2= yes, mainconnective= conjunction, relation= none, subformula1= c:C, subformula2= c:/Es.D, thing= proposition)')
# (5.7999, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (5.7999, 'PROCEDURAL', 'RULE SELECTED: retrieve second conjunct')
# (5.8499, 'PROCEDURAL', 'RULE FIRED: retrieve second conjunct')
# (5.8499, 'g', 'MODIFIED')
# (5.8499, 'retrieval', 'START RETRIEVAL')
# (Partially) matching chunk: proposition(derived= no, element= c, form= c:/Es.D, inferred1= , inferred2= , mainconnective= existential, relation= s, subformula1= y:D, subformula2= , thing= proposition)
# Base level learning: 0.0
# Spreading activation 0
# Partial matching 0
# Noise: 0
# Total activation 0.0
# Time to retrieve 0.1
# (5.8499, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (5.8499, 'PROCEDURAL', 'NO RULE FOUND')
# (5.9499, 'retrieval', 'CLEARED')
# (5.9499, 'retrieval', 'RETRIEVED: proposition(derived= no, element= c, form= c:/Es.D, inferred1= , inferred2= , mainconnective= existential, relation= s, subformula1= y:D, subformula2= , thing= proposition)')
# (5.9499, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (5.9499, 'PROCEDURAL', 'RULE SELECTED: label second conjunct as derived')
# (5.9999, 'PROCEDURAL', 'RULE RE-CREATED: label second conjunct as inferred and retrieve second conjunct')
# (5.9999, 'PROCEDURAL', 'RULE FIRED: label second conjunct as derived')
# (5.9999, 'g', 'MODIFIED')
# (5.9999, 'imaginal', 'CLEARED')
# (5.9999, 'imaginal', 'CREATED A CHUNK: proposition(derived= yes, element= c, form= c:/Es.D, inferred1= none, inferred2= none, mainconnective= existential, relation= none, subformula1= y:D, subformula2= None, thing= proposition)')
# (5.9999, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (5.9999, 'PROCEDURAL', 'RULE SELECTED: do we need to derive something new?')
# (6.0499, 'PROCEDURAL', 'RULE FIRED: do we need to derive something new?')
# (6.0499, 'g', 'MODIFIED')
# (6.0499, 'imaginal', 'CLEARED')
# (6.0499, 'retrieval', 'CLEARED')
# (6.0499, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (6.0499, 'PROCEDURAL', 'RULE SELECTED: find formula to apply rule to and conjunction found, second conjunct inferred? 1')
# (6.0999, 'PROCEDURAL', 'RULE RE-CREATED: label second conjunct as derived and do we need to derive something new?')
# (6.0999, 'PROCEDURAL', 'RULE FIRED: find formula to apply rule to and conjunction found, second conjunct inferred? 1')
# (6.0999, 'g', 'MODIFIED')
# (6.0999, 'retrieval', 'CLEARED')
# (6.0999, 'imaginal', 'CLEARED')
# (6.0999, 'imaginal', 'CREATED A CHUNK: proposition(derived= yes, element= a, form= a:A&/Es.F, inferred1= no, inferred2= no, mainconnective= conjunction, relation= none, subformula1= a:A, subformula2= a:/Es.F, thing= proposition)')
# (6.0999, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (6.0999, 'PROCEDURAL', 'RULE SELECTED: conjunction found, second conjunct inferred? 2')
# (6.1499, 'PROCEDURAL', 'RULE RE-CREATED: do we need to derive something new? and find formula to apply rule to and conjunction found, second conjunct inferred? 1')
# (6.1499, 'PROCEDURAL', 'RULE FIRED: conjunction found, second conjunct inferred? 2')
# (6.1499, 'g', 'MODIFIED')
# (6.1499, 'imaginal', 'MODIFIED')
# (6.1499, 'retrieval', 'START RETRIEVAL')
# (Partially) matching chunk: proposition(derived= yes, element= a, form= a:A&/Es.F, inferred1= none, inferred2= yes, mainconnective= conjunction, relation= none, subformula1= a:A, subformula2= a:/Es.F, thing= proposition)
# Base level learning: 1.791759469228055
# Spreading activation 0
# Partial matching 0
# Noise: 0
# Total activation 1.791759469228055
# Time to retrieve 0.01666666666666667
# (6.1499, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (6.1499, 'PROCEDURAL', 'NO RULE FOUND')
# (6.1666, 'retrieval', 'CLEARED')
# (6.1666, 'retrieval', 'RETRIEVED: proposition(derived= yes, element= a, form= a:A&/Es.F, inferred1= none, inferred2= yes, mainconnective= conjunction, relation= none, subformula1= a:A, subformula2= a:/Es.F, thing= proposition)')
# (6.1666, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (6.1666, 'PROCEDURAL', 'RULE SELECTED: first_conjunct_inferred_a')
# (6.2166, 'PROCEDURAL', 'RULE RE-CREATED: find formula to apply rule to and conjunction found, second conjunct inferred? 1 and conjunction found, second conjunct inferred? 2')
# (6.2166, 'PROCEDURAL', 'RULE FIRED: first_conjunct_inferred_a')
# (6.2166, 'g', 'MODIFIED')
# (6.2166, 'retrieval', 'CLEARED')
# (6.2166, 'imaginal', 'CLEARED')
# (6.2166, 'imaginal', 'CREATED A CHUNK: proposition(derived= yes, element= a, form= a:A&/Es.F, inferred1= none, inferred2= yes, mainconnective= conjunction, relation= none, subformula1= a:A, subformula2= a:/Es.F, thing= proposition)')
# (6.2166, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (6.2166, 'PROCEDURAL', 'RULE SELECTED: first_conjunct_inferred_b')
# (6.2666, 'PROCEDURAL', 'RULE RE-CREATED: conjunction found, second conjunct inferred? 2 and first_conjunct_inferred_a')
# (6.2666, 'PROCEDURAL', 'RULE FIRED: first_conjunct_inferred_b')
# (6.2666, 'g', 'MODIFIED')
# (6.2666, 'imaginal', 'MODIFIED')
# (6.2666, 'retrieval', 'START RETRIEVAL')
# (Partially) matching chunk: proposition(derived= yes, element= a, form= a:A&/Es.F, inferred1= yes, inferred2= yes, mainconnective= conjunction, relation= none, subformula1= a:A, subformula2= a:/Es.F, thing= proposition)
# Base level learning: 1.3862943611198906
# Spreading activation 0
# Partial matching 0
# Noise: 0
# Total activation 1.3862943611198906
# Time to retrieve 0.025
# (6.2666, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (6.2666, 'PROCEDURAL', 'NO RULE FOUND')
# (6.2916, 'retrieval', 'CLEARED')
# (6.2916, 'retrieval', 'RETRIEVED: proposition(derived= yes, element= a, form= a:A&/Es.F, inferred1= yes, inferred2= yes, mainconnective= conjunction, relation= none, subformula1= a:A, subformula2= a:/Es.F, thing= proposition)')
# (6.2916, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (6.2916, 'PROCEDURAL', 'RULE SELECTED: store in list 2')
# (6.3416, 'PROCEDURAL', 'RULE RE-CREATED: first_conjunct_inferred_a and first_conjunct_inferred_b')
# (6.3416, 'PROCEDURAL', 'RULE FIRED: store in list 2')
# (6.3416, 'g', 'MODIFIED')
# (6.3416, 'imaginal', 'CLEARED')
# (6.3416, 'imaginal', 'CREATED A CHUNK: storelist(derived= none, element= a, form10= none, form11= none, form12= none, form13= none, form14= none, form15= none, form2= none, form3= none, form4= none, form5= none, form6= none, form7= none, form8= none, form9= none, form= a:A&/Es.F, inferred1= none, inferred2= none, mainconnective= conjunction, relation= none, subformula1= a:A, subformula2= a:/Es.F, thing= storelist)')
# (6.3416, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (6.3416, 'PROCEDURAL', 'RULE SELECTED: retrieve the next proposition to store in the list')
# (6.3916, 'PROCEDURAL', 'RULE FIRED: retrieve the next proposition to store in the list')
# (6.3916, 'g', 'MODIFIED')
# (6.3916, 'retrieval', 'START RETRIEVAL')
# (6.3916, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (6.3916, 'PROCEDURAL', 'NO RULE FOUND')
# (6.4916, 'retrieval', 'RETRIEVED: None')
# (6.4916, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (6.4916, 'PROCEDURAL', 'RULE SELECTED: use the list to select the next formula')
# (6.5416, 'PROCEDURAL', 'RULE RE-CREATED: store in list 2 and retrieve the next proposition to store in the list')
# (6.5416, 'PROCEDURAL', 'RULE FIRED: use the list to select the next formula')
# (6.5416, 'g', 'MODIFIED')
# (6.5416, 'retrieval', 'START RETRIEVAL')
# ...
# (8.1999, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (8.1999, 'PROCEDURAL', 'RULE SELECTED: find clash 1')
# (8.2499, 'PROCEDURAL', 'RULE FIRED: find clash 1')
# (8.2499, 'g', 'MODIFIED')
# (8.2499, 'imaginal', 'CLEARED')
# (8.2499, 'retrieval', 'START RETRIEVAL')
# (8.2499, 'imaginal', 'CREATED A CHUNK: checklist(element= b, form2= b:B, form3= a:A, form4= b:B, form5= c:C, form6= none, form7= none, form8= , form= b:B, mainconnective= concept, relation= none, subformula1= B, subformula2= , thing= checklist)')
# (8.2499, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (8.2499, 'PROCEDURAL', 'NO RULE FOUND')
# (8.3499, 'retrieval', 'RETRIEVED: None')
# (8.3499, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (8.3499, 'PROCEDURAL', 'RULE SELECTED: no clash 1 and find next formula and repeat')
# (8.3999, 'PROCEDURAL', 'RULE FIRED: no clash 1 and find next formula and repeat')
# (8.3999, 'g', 'MODIFIED')
# (8.3999, 'retrieval', 'CLEARED')
# (8.3999, 'imaginal', 'CLEARED')
# (8.3999, 'imaginal', 'CREATED A CHUNK: checklist(element= b, form2= b:B, form3= b:B, form4= a:A, form5= b:B, form6= c:C, form7= none, form8= none, form= b:B, mainconnective= concept, relation= none, subformula1= B, subformula2= none, thing= checklist)')
# (8.3999, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (8.3999, 'PROCEDURAL', 'RULE SELECTED: find clash 1')
# (8.4499, 'PROCEDURAL', 'RULE FIRED: find clash 1')
# (8.4499, 'g', 'MODIFIED')
# (8.4499, 'imaginal', 'CLEARED')
# (8.4499, 'retrieval', 'START RETRIEVAL')
# (8.4499, 'imaginal', 'CREATED A CHUNK: checklist(element= b, form2= b:B, form3= b:B, form4= a:A, form5= b:B, form6= c:C, form7= none, form8= , form= b:B, mainconnective= concept, relation= none, subformula1= B, subformula2= , thing= checklist)')
# (8.4499, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (8.4499, 'PROCEDURAL', 'NO RULE FOUND')
# (8.5499, 'retrieval', 'RETRIEVED: None')
# (8.5499, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (8.5499, 'PROCEDURAL', 'RULE SELECTED: no clash 1 and find next formula and repeat')
# (8.5999, 'PROCEDURAL', 'RULE FIRED: no clash 1 and find next formula and repeat')
# (8.5999, 'g', 'MODIFIED')
# (8.5999, 'retrieval', 'CLEARED')
# (8.5999, 'imaginal', 'CLEARED')
# (8.5999, 'imaginal', 'CREATED A CHUNK: checklist(element= b, form2= b:B, form3= b:B, form4= b:B, form5= a:A, form6= b:B, form7= c:C, form8= none, form= b:B, mainconnective= concept, relation= none, subformula1= B, subformula2= none, thing= checklist)')
# (8.5999, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (8.5999, 'PROCEDURAL', 'RULE SELECTED: find clash 1')
# (8.6499, 'PROCEDURAL', 'RULE FIRED: find clash 1')
# (8.6499, 'g', 'MODIFIED')
# (8.6499, 'imaginal', 'CLEARED')
# (8.6499, 'retrieval', 'START RETRIEVAL')
# (8.6499, 'imaginal', 'CREATED A CHUNK: checklist(element= b, form2= b:B, form3= b:B, form4= b:B, form5= a:A, form6= b:B, form7= c:C, form8= , form= b:B, mainconnective= concept, relation= none, subformula1= B, subformula2= , thing= checklist)')
# (8.6499, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (8.6499, 'PROCEDURAL', 'NO RULE FOUND')
# (8.7499, 'retrieval', 'RETRIEVED: None')
# (8.7499, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (8.7499, 'PROCEDURAL', 'RULE SELECTED: no clash 1')
# (8.7999, 'PROCEDURAL', 'RULE FIRED: no clash 1')
# (8.7999, 'g', 'MODIFIED')
# (8.7999, 'retrieval', 'CLEARED')
# (8.7999, 'imaginal', 'CLEARED')
# (8.7999, 'imaginal', 'CREATED A CHUNK: checklist(element= none, form2= b:B, form3= b:B, form4= b:B, form5= b:B, form6= a:A, form7= b:B, form8= c:C, form= none, mainconnective= none, relation= none, subformula1= none, subformula2= none, thing= checklist)')
# (8.7999, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (8.7999, 'PROCEDURAL', 'RULE SELECTED: find next formula')
# (8.8499, 'PROCEDURAL', 'RULE FIRED: find next formula')
# (8.8499, 'g', 'MODIFIED')
# (8.8499, 'imaginal', 'MODIFIED')
# (8.8499, 'retrieval', 'START RETRIEVAL')
# (8.8499, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (8.8499, 'PROCEDURAL', 'NO RULE FOUND')
# (8.9499, 'retrieval', 'RETRIEVED: None')
# (8.9499, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (8.9499, 'PROCEDURAL', 'RULE SELECTED: move on')
# (8.9999, 'PROCEDURAL', 'RULE RE-CREATED: no clash 1 and find next formula')
# (8.9999, 'PROCEDURAL', 'RULE FIRED: move on')
# (8.9999, 'g', 'MODIFIED')
# (8.9999, 'retrieval', 'CLEARED')
# (8.9999, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (8.9999, 'PROCEDURAL', 'RULE SELECTED: find formula to apply rule to and conjunction found, second conjunct inferred? 1')
# (9.0499, 'PROCEDURAL', 'RULE FIRED: find formula to apply rule to and conjunction found, second conjunct inferred? 1')
# (9.0499, 'g', 'MODIFIED')
# (9.0499, 'retrieval', 'CLEARED')
# (9.0499, 'imaginal', 'CLEARED')
# (9.0499, 'imaginal', 'CREATED A CHUNK: proposition(derived= yes, element= a, form= a:A&/Es.F, inferred1= no, inferred2= no, mainconnective= conjunction, relation= none, subformula1= a:A, subformula2= a:/Es.F, thing= proposition)')
# (9.0499, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (9.0499, 'PROCEDURAL', 'RULE SELECTED: conjunction found, second conjunct inferred? 2 and first_conjunct_inferred_a and first_conjunct_inferred_b')
# (9.0999, 'PROCEDURAL', 'RULE RE-CREATED: move on and find formula to apply rule to and conjunction found, second conjunct inferred? 1')
# (9.0999, 'PROCEDURAL', 'RULE FIRED: conjunction found, second conjunct inferred? 2 and first_conjunct_inferred_a and first_conjunct_inferred_b')
# (9.0999, 'g', 'MODIFIED')
# (9.0999, 'imaginal', 'MODIFIED')
# (9.0999, 'retrieval', 'START RETRIEVAL')
# (Partially) matching chunk: proposition(derived= yes, element= a, form= a:A&/Es.F, inferred1= yes, inferred2= yes, mainconnective= conjunction, relation= none, subformula1= a:A, subformula2= a:/Es.F, thing= proposition)
# Base level learning: 1.6094379124341003
# Spreading activation 0
# Partial matching 0
# Noise: 0
# Total activation 1.6094379124341003
# Time to retrieve 0.020000000000000004
# (9.0999, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (9.0999, 'PROCEDURAL', 'NO RULE FOUND')
# (9.1199, 'retrieval', 'CLEARED')
# (9.1199, 'retrieval', 'RETRIEVED: proposition(derived= yes, element= a, form= a:A&/Es.F, inferred1= yes, inferred2= yes, mainconnective= conjunction, relation= none, subformula1= a:A, subformula2= a:/Es.F, thing= proposition)')
# (9.1199, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (9.1199, 'PROCEDURAL', 'RULE SELECTED: store in list 2')
# (9.1699, 'PROCEDURAL', 'RULE CREATED: find formula to apply rule to and conjunction found, second conjunct inferred? 1 and conjunction found, second conjunct inferred? 2 and first_conjunct_inferred_a and first_conjunct_inferred_b')
# (9.1699, 'PROCEDURAL', 'RULE FIRED: store in list 2')
# (9.1699, 'g', 'MODIFIED')
# (9.1699, 'imaginal', 'CLEARED')
# (9.1699, 'imaginal', 'CREATED A CHUNK: storelist(derived= none, element= a, form10= none, form11= none, form12= none, form13= none, form14= none, form15= none, form2= none, form3= none, form4= none, form5= none, form6= none, form7= none, form8= none, form9= none, form= a:A&/Es.F, inferred1= none, inferred2= none, mainconnective= conjunction, relation= none, subformula1= a:A, subformula2= a:/Es.F, thing= storelist)')
# (9.1699, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (9.1699, 'PROCEDURAL', 'RULE SELECTED: retrieve the next proposition to store in the list')
# (9.2199, 'PROCEDURAL', 'RULE FIRED: retrieve the next proposition to store in the list')
# (9.2199, 'g', 'MODIFIED')
# (9.2199, 'retrieval', 'START RETRIEVAL')
# (Partially) matching chunk: proposition(derived= yes, element= c, form= c:C&/Es.D, inferred1= yes, inferred2= yes, mainconnective= conjunction, relation= none, subformula1= c:C, subformula2= c:/Es.D, thing= proposition)
# Base level learning: 0.6931471805599453
# Spreading activation 0
# Partial matching 0
# Noise: 0
# Total activation 0.6931471805599453
# Time to retrieve 0.05
# (9.2199, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (9.2199, 'PROCEDURAL', 'NO RULE FOUND')
# (9.2699, 'retrieval', 'CLEARED')
# (9.2699, 'retrieval', 'RETRIEVED: proposition(derived= yes, element= c, form= c:C&/Es.D, inferred1= yes, inferred2= yes, mainconnective= conjunction, relation= none, subformula1= c:C, subformula2= c:/Es.D, thing= proposition)')
# (9.2699, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (9.2699, 'PROCEDURAL', 'RULE SELECTED: store the next proposition in the list')
# (9.3199, 'PROCEDURAL', 'RULE RE-CREATED: store in list 2 and retrieve the next proposition to store in the list')
# (9.3199, 'PROCEDURAL', 'RULE FIRED: store the next proposition in the list')
# (9.3199, 'g', 'MODIFIED')
# (9.3199, 'imaginal', 'CLEARED')
# (9.3199, 'imaginal', 'CREATED A CHUNK: storelist(derived= yes, element= c, form10= none, form11= none, form12= none, form13= none, form14= none, form15= none, form2= a:A&/Es.F, form3= none, form4= none, form5= none, form6= none, form7= none, form8= none, form9= none, form= c:C&/Es.D, inferred1= yes, inferred2= yes, mainconnective= conjunction, relation= none, subformula1= c:C, subformula2= c:/Es.D, thing= storelist)')
# (9.3199, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (9.3199, 'PROCEDURAL', 'RULE SELECTED: retrieve the next proposition to store in the list')
# (9.3699, 'PROCEDURAL', 'RULE FIRED: retrieve the next proposition to store in the list')
# (9.3699, 'g', 'MODIFIED')
# (9.3699, 'retrieval', 'START RETRIEVAL')
# (9.3699, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (9.3699, 'PROCEDURAL', 'NO RULE FOUND')
# (9.4699, 'retrieval', 'RETRIEVED: None')
# (9.4699, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (9.4699, 'PROCEDURAL', 'RULE SELECTED: use the list to select the next formula and conjunction found, second conjunct inferred? 1')
# (9.5199, 'PROCEDURAL', 'RULE CREATED: store the next proposition in the list and retrieve the next proposition to store in the list')
# (9.5199, 'PROCEDURAL', 'RULE FIRED: use the list to select the next formula and conjunction found, second conjunct inferred? 1')
# (9.5199, 'g', 'MODIFIED')
# (9.5199, 'retrieval', 'CLEARED')
# (9.5199, 'imaginal', 'CLEARED')
# (9.5199, 'imaginal', 'CREATED A CHUNK: proposition(derived= yes, element= c, form= c:C&/Es.D, inferred1= no, inferred2= no, mainconnective= conjunction, relation= none, subformula1= c:C, subformula2= c:/Es.D, thing= proposition)')
# (9.5199, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (9.5199, 'PROCEDURAL', 'RULE SELECTED: conjunction found, second conjunct inferred? 2 and first_conjunct_inferred_a 1')
# (9.5699, 'PROCEDURAL', 'RULE FIRED: conjunction found, second conjunct inferred? 2 and first_conjunct_inferred_a 1')
# (9.5699, 'g', 'MODIFIED')
# (9.5699, 'retrieval', 'CLEARED')
# (9.5699, 'imaginal', 'CLEARED')
# (9.5699, 'imaginal', 'CREATED A CHUNK: proposition(derived= yes, element= c, form= c:C&/Es.D, inferred1= none, inferred2= yes, mainconnective= conjunction, relation= none, subformula1= c:C, subformula2= c:/Es.D, thing= proposition)')
# (9.5699, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (9.5699, 'PROCEDURAL', 'RULE SELECTED: first_conjunct_inferred_b')
# (9.6199, 'PROCEDURAL', 'RULE FIRED: first_conjunct_inferred_b')
# (9.6199, 'g', 'MODIFIED')
# (9.6199, 'imaginal', 'MODIFIED')
# (9.6199, 'retrieval', 'START RETRIEVAL')
# (Partially) matching chunk: proposition(derived= yes, element= c, form= c:C&/Es.D, inferred1= yes, inferred2= yes, mainconnective= conjunction, relation= none, subformula1= c:C, subformula2= c:/Es.D, thing= proposition)
# Base level learning: 1.0986122886681098
# Spreading activation 0
# Partial matching 0
# Noise: 0
# Total activation 1.0986122886681098
# Time to retrieve 0.03333333333333333
# (9.6199, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (9.6199, 'PROCEDURAL', 'NO RULE FOUND')
# (9.6532, 'retrieval', 'CLEARED')
# (9.6532, 'retrieval', 'RETRIEVED: proposition(derived= yes, element= c, form= c:C&/Es.D, inferred1= yes, inferred2= yes, mainconnective= conjunction, relation= none, subformula1= c:C, subformula2= c:/Es.D, thing= proposition)')
# (9.6532, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (9.6532, 'PROCEDURAL', 'RULE SELECTED: store in list 2')
# (9.7032, 'PROCEDURAL', 'RULE CREATED: conjunction found, second conjunct inferred? 2 and first_conjunct_inferred_a 1 and first_conjunct_inferred_b')
# (9.7032, 'PROCEDURAL', 'RULE FIRED: store in list 2')
# (9.7032, 'g', 'MODIFIED')
# (9.7032, 'imaginal', 'CLEARED')
# (9.7032, 'imaginal', 'CREATED A CHUNK: storelist(derived= none, element= c, form10= none, form11= none, form12= none, form13= none, form14= none, form15= none, form2= none, form3= none, form4= none, form5= none, form6= none, form7= none, form8= none, form9= none, form= c:C&/Es.D, inferred1= none, inferred2= none, mainconnective= conjunction, relation= none, subformula1= c:C, subformula2= c:/Es.D, thing= storelist)')
# (9.7032, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (9.7032, 'PROCEDURAL', 'RULE SELECTED: retrieve the next proposition to store in the list')
# (9.7532, 'PROCEDURAL', 'RULE FIRED: retrieve the next proposition to store in the list')
# (9.7532, 'g', 'MODIFIED')
# (9.7532, 'retrieval', 'START RETRIEVAL')
# (Partially) matching chunk: proposition(derived= yes, element= a, form= a:A&/Es.F, inferred1= yes, inferred2= yes, mainconnective= conjunction, relation= none, subformula1= a:A, subformula2= a:/Es.F, thing= proposition)
# Base level learning: 1.791759469228055
# Spreading activation 0
# Partial matching 0
# Noise: 0
# Total activation 1.791759469228055
# Time to retrieve 0.01666666666666667
# (9.7532, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (9.7532, 'PROCEDURAL', 'NO RULE FOUND')
# (9.7699, 'retrieval', 'CLEARED')
# (9.7699, 'retrieval', 'RETRIEVED: proposition(derived= yes, element= a, form= a:A&/Es.F, inferred1= yes, inferred2= yes, mainconnective= conjunction, relation= none, subformula1= a:A, subformula2= a:/Es.F, thing= proposition)')
# (9.7699, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (9.7699, 'PROCEDURAL', 'RULE SELECTED: store the next proposition in the list')
# (9.8199, 'PROCEDURAL', 'RULE RE-CREATED: store in list 2 and retrieve the next proposition to store in the list')
# (9.8199, 'PROCEDURAL', 'RULE FIRED: store the next proposition in the list')
# (9.8199, 'g', 'MODIFIED')
# (9.8199, 'imaginal', 'CLEARED')
# (9.8199, 'imaginal', 'CREATED A CHUNK: storelist(derived= yes, element= a, form10= none, form11= none, form12= none, form13= none, form14= none, form15= none, form2= c:C&/Es.D, form3= none, form4= none, form5= none, form6= none, form7= none, form8= none, form9= none, form= a:A&/Es.F, inferred1= yes, inferred2= yes, mainconnective= conjunction, relation= none, subformula1= a:A, subformula2= a:/Es.F, thing= storelist)')
# (9.8199, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (9.8199, 'PROCEDURAL', 'RULE SELECTED: retrieve the next proposition to store in the list')
# (9.8699, 'PROCEDURAL', 'RULE FIRED: retrieve the next proposition to store in the list')
# (9.8699, 'g', 'MODIFIED')
# (9.8699, 'retrieval', 'START RETRIEVAL')
# (9.8699, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (9.8699, 'PROCEDURAL', 'NO RULE FOUND')
# (9.9699, 'retrieval', 'RETRIEVED: None')
# (9.9699, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (9.9699, 'PROCEDURAL', 'RULE SELECTED: use the list to select the next formula')
# (10.0199, 'PROCEDURAL', 'RULE RE-CREATED: store the next proposition in the list and retrieve the next proposition to store in the list')
# (10.0199, 'PROCEDURAL', 'RULE FIRED: use the list to select the next formula')
# (10.0199, 'g', 'MODIFIED')
# (10.0199, 'retrieval', 'START RETRIEVAL')
# (10.0199, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (10.0199, 'PROCEDURAL', 'NO RULE FOUND')
# (10.1199, 'retrieval', 'RETRIEVED: None')
# (10.1199, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (10.1199, 'PROCEDURAL', 'RULE SELECTED: confirm consistency')
# (10.1699, 'PROCEDURAL', 'RULE FIRED: confirm consistency')
# (10.1699, 'g', 'MODIFIED')
# (10.1699, 'manual', 'COMMAND: press_key')
# (10.1699, 'manual', 'PREPARATION COMPLETE')
# (10.1699, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (10.1699, 'PROCEDURAL', 'NO RULE FOUND')
# (10.2199, 'manual', 'INITIATION COMPLETE')
# (10.2199, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (10.2199, 'PROCEDURAL', 'NO RULE FOUND')
# (10.3199, 'manual', 'KEY PRESSED: N')
# (10.3199, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (10.3199, 'PROCEDURAL', 'NO RULE FOUND')
# (10.4699, 'manual', 'MOVEMENT FINISHED')
# (10.4699, 'PROCEDURAL', 'CONFLICT RESOLUTION')
# (10.4699, 'PROCEDURAL', 'NO RULE FOUND')

# %%
dm
# Out:
# {proposition(derived= yes, element= godel, form= godel:(austrian&logician)&(Einsteinsfriend&incomplete), inferred1= no, inferred2= no, mainconnective= conjunction, relation= , subformula1= godel:austrian&logician, subformula2= godel:Einsteinsfriend&incomplete, thing= proposition): array([0.    , 0.4   , 0.6   , 1.0333]), proposition(derived= yes, element= godel, form= godel:austrian&(logician&(Einsteinsfriend&incomplete)), inferred1= no, inferred2= no, mainconnective= conjunction, relation= , subformula1= godel:austrian, subformula2= godel:logician&(Einsteinsfriend&incomplete), thing= proposition): array([0.]), proposition(derived= yes, element= godel, form= godel:austrian&((logician&Einsteinsfriend)&incomplete), inferred1= no, inferred2= no, mainconnective= conjunction, relation= , subformula1= godel:austrian, subformula2= godel:(logician&Einsteinsfriend)&incomplete, thing= proposition): array([0.]), proposition(derived= yes, element= godel, form= godel:(austrian&(logician&Einsteinsfriend))&incomplete, inferred1= no, inferred2= no, mainconnective= conjunction, relation= , subformula1= godel:austrian&(logician&Einsteinsfriend), subformula2= godel:incomplete, thing= proposition): array([0.]), proposition(derived= no, element= godel, form= godel:austrian&logician, inferred1= no, inferred2= no, mainconnective= conjunction, relation= , subformula1= godel:austrian, subformula2= godel:logician, thing= proposition): array([0. , 0.9]), proposition(derived= no, element= godel, form= godel:Einsteinsfriend&incomplete, inferred1= no, inferred2= no, mainconnective= conjunction, relation= , subformula1= godel:Einsteinsfriend, subformula2= godel:incomplete, thing= proposition): array([0.]), proposition(derived= no, element= godel, form= godel:austrian, inferred1= , inferred2= , mainconnective= concept, relation= , subformula1= austrian, subformula2= , thing= proposition): array([0.]), proposition(derived= no, element= godel, form= godel:logician, inferred1= , inferred2= , mainconnective= concept, relation= , subformula1= logician, subformula2= , thing= proposition): array([0.]), proposition(derived= no, element= godel, form= godel:Einsteinsfriend, inferred1= , inferred2= , mainconnective= concept, relation= , subformula1= Einsteinsfriend, subformula2= , thing= proposition): array([0.]), proposition(derived= no, element= godel, form= godel:incomplete, inferred1= , inferred2= , mainconnective= concept, relation= , subformula1= incomplete, subformula2= , thing= proposition): array([0.]), proposition(derived= no, element= godel, form= godel:logician&(Einsteinsfriend&incomplete), inferred1= no, inferred2= no, mainconnective= conjunction, relation= , subformula1= godel:logician, subformula2= godel:Einsteinsfriend&incomplete, thing= proposition): array([0.]), proposition(derived= no, element= godel, form= godel:(logician&Einsteinsfriend)&incomplete, inferred1= no, inferred2= no, mainconnective= conjunction, relation= , subformula1= godel:logician&Einsteinsfriend, subformula2= godel:incomplete, thing= proposition): array([0.]), proposition(derived= no, element= godel, form= godel:austrian&(logician&Einsteinsfriend), inferred1= no, inferred2= no, mainconnective= conjunction, relation= , subformula1= godel:austrian, subformula2= godel:logician&Einsteinsfriend, thing= proposition): array([0.]), proposition(derived= no, element= godel, form= godel:logician&Einsteinsfriend, inferred1= no, inferred2= no, mainconnective= conjunction, relation= , subformula1= godel:logician, subformula2= godel:Einsteinsfriend, thing= proposition): array([0.]), checklist(element= , form2= , form3= , form4= , form5= , form6= , form7= , form8= , form= , mainconnective= , relation= , subformula1= , subformula2= ): array([0.4]), proposition(derived= yes, element= godel, form= godel:(austrian&logician)&(Einsteinsfriend&incomplete), inferred1= yes, inferred2= , mainconnective= conjunction, relation= , subformula1= godel:austrian&logician, subformula2= godel:Einsteinsfriend&incompl ...

# %%
retrieval
# Out:
# {proposition(derived= yes, element= giacomo, form= giacomo:dutch, inferred1= , inferred2= , mainconnective= concept, relation= , subformula1= dutch, subformula2= , thing= proposition)}

# %%
goal
# Out:
# {goal(state= stop)}

# %%
imaginal
# Out:
# {checklist(element= giacomo, form2= none, form3= none, form4= none, form5= none, form6= none, form7= none, form8= none, form= giacomo:ndutch, mainconnective= negation, relation= none, subformula1= dutch, subformula2= none, thing= checklist)}

# %%
imaginal_action
# Out:
# set()

# %%
production
# Out:
# find first formula{'=g': goal(state= start), '=imaginal': checklist(element= , form2= , form3= , form4= , form5= , form6= , form7= , form8= , form= , mainconnective= , relation= , subformula1= , subformula2= ), '?retrieval': {'state': 'free'}}
# ==>
# {'=g': goal(state= store), '+retrieval': proposition(derived= yes, element= , form= , inferred1= , inferred2= , mainconnective= ~disjunction~relation~existential~conjunction~universal, relation= , subformula1= , subformula2= , thing= proposition)}
# skip and derive first formula{'=g': goal(state= store), '=imaginal': checklist(element= , form2= , form3= , form4= , form5= , form6= , form7= , form8= , form= , mainconnective= , relation= , subformula1= , subformula2= ), '?retrieval': {'state': 'error'}}
# ==>
# {'=g': goal(state= module2), '~retrieval': None}
# store first formula{'=g': goal(state= store), '=imaginal': checklist(element= , form2= , form3= , form4= , form5= , form6= , form7= , form8= , form= , mainconnective= , relation= , subformula1= , subformula2= ), '=retrieval': proposition(derived= , element= =X, form= =U, inferred1= , inferred2= , mainconnective= =Y, relation= , subformula1= =Z, subformula2= , thing= proposition)}
# ==>
# {'=g': goal(state= find_clash), '+imaginal': checklist(element= =X, form2= , form3= , form4= , form5= , form6= , form7= , form8= , form= =U, mainconnective= =Y, relation= , subformula1= =Z, subformula2= )}
# find clash 1{'=g': goal(state= find_clash), '=imaginal': checklist(element= =X, form2= =A, form3= =B, form4= =C, form5= =D, form6= =E, form7= =F, form8= , form= =Z, mainconnective= concept, relation= , subformula1= =Y, subformula2= ), '?retrieval': {'state': 'free'}}
# ==>
# {'=g': goal(state= signal_clash), '+imaginal': checklist(element= =X, form2= =A, form3= =B, form4= =C, form5= =D, form6= =E, form7= =F, form8= , form= =Z, mainconnective= concept, relation= , subformula1= =Y, subformula2= ), '+retrieval': proposition(derived= yes, element= =X, form= , inferred1= , inferred2= , mainconnective= negation, relation= , subformula1= =Y, subformula2= , thing= proposition)}
# show clash 1{'=g': goal(state= signal_clash), '=imaginal': checklist(element= =X, form2= , form3= , form4= , form5= , form6= , form7= , form8= , form= , mainconnective= concept, relation= , subformula1= =Y, subformula2= ), '=retrieval': proposition(derived= , element= =X, form= , inferred1= , inferred2= , mainconnective= negation, relation= , subformula1= =Y, subformula2= , thing= proposition), '?manual': {'state': 'free'}}
# ==>
# {'=g': goal(state= select), '+manual': _manual(cmd= press_key, key= C)}
# no clash 1{'=g': goal(state= signal_clash), '=imaginal': checklist(element= =X, form2= =A, form3= =B, form4= =C, form5= =D, form6= =E, form7= =F, form8= , form= =Z, mainconnective= concept, relation= , subformula1= =Y, subformula2= ), '?retrieval': {'state': 'error'}}
# ==>
# {'=g': goal(state= find_next_formula), '+imaginal': checklist(element= , form2= =Z, form3= =A, form4= =B, form5= =C, form6= =D, form7= =E, form8= =F, form= , mainconnective= , relation= , subformula1= , subformula2= ), '~retrieval': None}
# find clash 2{'=g': goal(state= find_clash), '=imaginal': checklist(element= =X, form2= , form3= , form4= , form5= , form6= , form7= , form8= , form= , mainconnective= negation, relation= , subformula1= =Y, subformula2= ), '?retrieval': {'state': 'free'}}
# ==>
# {'=g': goal(state= signal_clash), '+retrieval': proposition(derived= yes, element= =X, form= , inferred1= , inferred2= , mainconnective= concept, relation= , subformula1= =Y, subformula2= , thing= proposition)}
# show clash 2{'=g': goal(state= signal_clash), '=imaginal': checklist(element= =X, form2= , form3= , form4= , form5= , form6= , form7= , form8= , form= , mainconnective= negation, relation= , subformula1= =Y, subformula2= ), '=retrieval': proposition(derived= , element= =X, form= , inferred1= , inferred2= , mainconnective= concept, relation= , subformula1= =Y, subformula2= , thing= proposition), '?manual': {'state': 'free'}}
# ==>
# {'=g': goal(state= select), '+manual': _manual(cmd= press_key, key= C)}
# no clash 2{'=g': goal(state= signal_clash), '=imaginal': checklist(element= =X, form2= =U1, form3= =U2, form4= =U3, form5= =U4, form6= =U5, form7= =U6, form8= , form= =Z, mainconnective= negation, relation= , subformula1= =Y, subformula2= ), '?retrieval': {'state': 'error'}}
# ==>
# {'=g': goal(state= find_next_formula), '+imaginal': checklist(element= , form2= =Z, form3= =U1, form4= =U2, form5= =U3, form6= =U4, form7= =U5, form8= =U6, form= , mainconnective= , relation= , subformula1= , subformula2= ), '~retrieval': None}
# find next formula{'=g': goal(state= find_next_formula), '=imaginal': checklist(element= , form2= =U0, form3= =U1, form4= =U2, form5= =U3, form6= =U4, form7= =U5, form8= =U6, form= , mainconnective= , relation= , subformula1= , subformula2= ), '?retrieval': {'state': 'free'}}
# ==>
# {'=g': goal(state= decide), '+retrieval': proposition(derived= yes, element= , form= ~=U0~=U6~=U5~=U1~=U4~=U2~=U3, inferred1= , inferred2= , mainconnective= ~disjunction~relation~existential~conjunction~universal, relation= , subformula1= , subformula2= , thing= proposition)}
# repeat{'=g': goal(state= decide), '=retrieval': proposition(derived= , element= =X, form= =U, inferred1= , inferred2= , mainconnective= =Y, relation= , subformula1= =Z, subformula2= , thing= proposition), '=imaginal': checklist(element= , form2= =U0, form3= =U1, form4= =U2, form5= =U3, form6= =U4, form7= =U5, form8= =U6, form= , mainconnective= , relation= , subformula1= , subformula2= )}
# ==>
# {'=g': goal(state= find_clash), '+imaginal': checklist(element= =X, form2= =U0, form3= =U1, form4= =U2, form5= =U3, form6= =U4, form7= =U5, form8= =U6, form= =U, mainconnective= =Y, relation= , subformula1= =Z, subformula2= ), '~retrieval': None}
# move on{'=g': goal(state= decide), '?retrieval': {'state': 'error'}}
# ==>
# {'=g': goal(state= module2), '~retrieval': None}
# find formula to apply rule to{'=g': goal(state= module2), '?retrieval': {'state': 'free'}}
# ==>
# {'=g': goal(state= find_rule), '+retrieval': proposition(derived= yes, element= , form= , inferred1= , inferred2= , mainconnective= conjunction, relation= , subformula1= , subformula2= , thing= proposition)}
# conjunction found, first conjunct inferred? 1{'=g': goal(state= find_rule), '?retrieval': {'state': 'free'}, '=retrieval': proposition(derived= yes, element= =U, form= =X, inferred1= , inferred2= , mainconnective= conjunction, relation= , subformula1= =Y, subformula2= =Z, thing= proposition)}
# ==>
# {'=g': goal(state= first_conjunct_inferred1), '+imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= no, inferred2= no, mainconnective= conjunction, relation= , subformula1= =Y, subformula2= =Z, thing= proposition), '~retrieval': None}
# conjunction found, first conjunct inferred? 2{'=g': goal(state= first_conjunct_inferred1), '=imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= no, inferred2= no, mainconnective= conjunction, relation= , subformula1= =Y, subformula2= =Z, thing= proposition), '?retrieval': {'state': 'free'}}
# ==>
# {'=g': goal(state= first_conjunct_inferred2), '+retrieval': proposition(derived= , element= , form= =X, inferred1= yes, inferred2= , mainconnective= conjunction, relation= , subformula1= , subformula2= , thing= proposition), '=imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= no, inferred2= no, mainconnective= conjunction, relation= , subformula1= =Y, subformula2= =Z, thing= proposition)}
# label first conjunct as inferred{'=g': goal(state= first_conjunct_inferred2), '?retrieval': {'state': 'error'}, '=imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= , inferred2= , mainconnective= conjunction, relation= , subformula1= =Y, subformula2= =Z, thing= proposition)}
# ==>
# {'=g': goal(state= retrieve_first_conjunct), '+imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= yes, inferred2= , mainconnective= conjunction, relation= , subformula1= =Y, subformula2= =Z, thing= proposition), '~retrieval': None}
# retrieve first conjunct{'=g': goal(state= retrieve_first_conjunct), '=imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= yes, inferred2= , mainconnective= conjunction, relation= , subformula1= =Y, subformula2= =Z, thing= proposition), '?retrieval': {'state': 'free'}}
# ==>
# {'=g': goal(state= label_first_conjunct), '+retrieval': proposition(derived= , element= , form= =Y, inferred1= , inferred2= , mainconnective= , relation= , subformula1= , subformula2= , thing= proposition)}
# label first conjunct as derived{'=g': goal(state= label_first_conjunct), '=retrieval': proposition(derived= , element= =U, form= =X, inferred1= , inferred2= , mainconnective= =V, relation= , subformula1= =Y, subformula2= =Z, thing= proposition), '?imaginal': {'state': 'free'}}
# ==>
# {'=g': goal(state= prepare_module3), '+imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= , inferred2= , mainconnective= =V, relation= , subformula1= =Y, subformula2= =Z, thing= proposition)}
# proceed to module 3{'=g': goal(state= prepare_module3), '=imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= , inferred2= , mainconnective= =V, relation= , subformula1= =Y, subformula2= =Z, thing= proposition)}
# ==>
# {'=g': goal(state= module3)}
# second_conjunct_inferred_a{'=g': goal(state= first_conjunct_inferred2), '?retrieval': {'buffer': 'full'}, '=retrieval': proposition(derived= =S, element= =Y, form= =X, inferred1= yes, inferred2= =W, mainconnective= conjunction, relation= =Z, subformula1= =U, subformula2= =V, thing= proposition), '?imaginal': {'state': 'free'}}
# ==>
# {'=g': goal(state= pre_infer_second_conjunct_after_first), '+imaginal': proposition(derived= =S, element= =Y, form= =X, inferred1= yes, inferred2= =W, mainconnective= conjunction, relation= =Z, subformula1= =U, subformula2= =V, thing= proposition), '~retrieval': None}
# second_conjunct_inferred_b{'=g': goal(state= pre_infer_second_conjunct_after_first), '=imaginal': proposition(derived= =S, element= =Y, form= =X, inferred1= yes, inferred2= =W, mainconnective= conjunction, relation= =Z, subformula1= =U, subformula2= =V, thing= proposition), '?retrieval': {'state': 'free'}}
# ==>
# {'=g': goal(state= infer_second_conjunct_after_first), '+retrieval': proposition(derived= =S, element= =Y, form= =X, inferred1= yes, inferred2= yes, mainconnective= conjunction, relation= =Z, subformula1= =U, subformula2= =V, thing= proposition), '=imaginal': proposition(derived= =S, element= =Y, form= =X, inferred1= yes, inferred2= =W, mainconnective= conjunction, relation= =Z, subformula1= =U, subformula2= =V, thing= proposition)}
# store in list 1{'=g': goal(state= infer_second_conjunct_after_first), '=retrieval': proposition(derived= , element= =Y, form= =X, inferred1= yes, inferred2= yes, mainconnective= =Z, relation= =U, subformula1= =V, subformula2= =W, thing= proposition), '?retrieval': {'state': 'free'}}
# ==>
# {'=g': goal(state= store_in_list), '+imaginal': storelist(derived= , element= =Y, form10= , form11= , form12= , form13= , form14= , form15= , form2= , form3= , form4= , form5= , form6= , form7= , form8= , form9= , form= =X, inferred1= , inferred2= , mainconnective= =Z, relation= =U, subformula1= =V, subformula2= =W)}
# label second conjunct as inferred after first{'=g': goal(state= infer_second_conjunct_after_first), '?retrieval': {'state': 'error'}, '=imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= , inferred2= , mainconnective= conjunction, relation= , subformula1= =Y, subformula2= =Z, thing= proposition)}
# ==>
# {'=g': goal(state= retrieve_second_conjunct_after_first), '+imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= yes, inferred2= yes, mainconnective= conjunction, relation= , subformula1= =Y, subformula2= =Z, thing= proposition), '~retrieval': None}
# retrieve second conjunct after first{'=g': goal(state= retrieve_second_conjunct_after_first), '=imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= yes, inferred2= yes, mainconnective= conjunction, relation= , subformula1= =Y, subformula2= =Z, thing= proposition), '?retrieval': {'state': 'free'}}
# ==>
# {'=g': goal(state= label_second_conjunct_after_first), '+retrieval': proposition(derived= , element= , form= =Z, inferred1= , inferred2= , mainconnective= , relation= , subformula1= , subformula2= , thing= proposition)}
# label second conjunct as derived after first{'=g': goal(state= label_second_conjunct_after_first), '?retrieval': {'state': 'free'}, '=retrieval': proposition(derived= , element= =U, form= =X, inferred1= , inferred2= , mainconnective= =V, relation= , subformula1= =Y, subformula2= =Z, thing= proposition), '?imaginal': {'state': 'free'}}
# ==>
# {'=g': goal(state= prepare_module3), '+imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= , inferred2= , mainconnective= =V, relation= , subformula1= =Y, subformula2= =Z, thing= proposition)}
# conjunction found, second conjunct inferred? 1{'=g': goal(state= find_rule), '?retrieval': {'state': 'free'}, '=retrieval': proposition(derived= yes, element= =U, form= =X, inferred1= , inferred2= , mainconnective= conjunction, relation= , subformula1= =Y, subformula2= =Z, thing= proposition)}
# ==>
# {'=g': goal(state= second_conjunct_inferred1), '~retrieval': None, '+imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= no, inferred2= no, mainconnective= conjunction, relation= , subformula1= =Y, subformula2= =Z, thing= proposition)}
# conjunction found, second conjunct inferred? 2{'=g': goal(state= second_conjunct_inferred1), '=imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= no, inferred2= no, mainconnective= conjunction, relation= , subformula1= =Y, subformula2= =Z, thing= proposition), '?retrieval': {'state': 'free'}}
# ==>
# {'=g': goal(state= second_conjunct_inferred2), '+retrieval': proposition(derived= , element= , form= =X, inferred1= , inferred2= yes, mainconnective= conjunction, relation= , subformula1= , subformula2= , thing= proposition), '=imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= no, inferred2= no, mainconnective= conjunction, relation= , subformula1= =Y, subformula2= =Z, thing= proposition)}
# label second conjunct as inferred{'=g': goal(state= second_conjunct_inferred2), '?retrieval': {'state': 'error'}, '=imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= , inferred2= , mainconnective= conjunction, relation= , subformula1= =Y, subformula2= =Z, thing= proposition)}
# ==>
# {'=g': goal(state= retrieve_second_conjunct), '+imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= , inferred2= yes, mainconnective= conjunction, relation= , subformula1= =Y, subformula2= =Z, thing= proposition), '~retrieval': None}
# retrieve second conjunct{'=g': goal(state= retrieve_second_conjunct), '=imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= , inferred2= yes, mainconnective= conjunction, relation= , subformula1= =Y, subformula2= =Z, thing= proposition), '?retrieval': {'state': 'free'}}
# ==>
# {'=g': goal(state= label_second_conjunct), '+retrieval': proposition(derived= , element= , form= =Z, inferred1= , inferred2= , mainconnective= , relation= , subformula1= , subformula2= , thing= proposition)}
# label second conjunct as derived{'=g': goal(state= label_second_conjunct), '=retrieval': proposition(derived= , element= =U, form= =X, inferred1= , inferred2= , mainconnective= =V, relation= , subformula1= =Y, subformula2= =Z, thing= proposition), '?imaginal': {'state': 'free'}}
# ==>
# {'=g': goal(state= prepare_module3), '+imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= , inferred2= , mainconnective= =V, relation= , subformula1= =Y, subformula2= =Z, thing= proposition)}
# first_conjunct_inferred_a{'=g': goal(state= second_conjunct_inferred2), '?retrieval': {'buffer': (['~', 'empty'], {})}, '=retrieval': proposition(derived= =S, element= =Y, form= =X, inferred1= =W, inferred2= yes, mainconnective= conjunction, relation= =Z, subformula1= =U, subformula2= =V, thing= proposition), '?imaginal': {'state': 'free'}}
# ==>
# {'=g': goal(state= pre_infer_first_conjunct_after_second), '+imaginal': proposition(derived= =S, element= =Y, form= =X, inferred1= =W, inferred2= yes, mainconnective= conjunction, relation= =Z, subformula1= =U, subformula2= =V, thing= proposition), '~retrieval': None}
# first_conjunct_inferred_b{'=g': goal(state= pre_infer_first_conjunct_after_second), '=imaginal': proposition(derived= =S, element= =Y, form= =X, inferred1= =W, inferred2= yes, mainconnective= conjunction, relation= =Z, subformula1= =U, subformula2= =V, thing= proposition), '?retrieval': {'state': 'free'}}
# ==>
# {'=g': goal(state= infer_first_conjunct_after_second), '+retrieval': proposition(derived= =S, element= =Y, form= =X, inferred1= yes, inferred2= yes, mainconnective= conjunction, relation= =Z, subformula1= =U, subformula2= =V, thing= proposition), '=imaginal': proposition(derived= =S, element= =Y, form= =X, inferred1= =W, inferred2= yes, mainconnective= conjunction, relation= =Z, subformula1= =U, subformula2= =V, thing= proposition)}
# store in list 2{'=g': goal(state= infer_first_conjunct_after_second), '=retrieval': proposition(derived= , element= =Y, form= =X, inferred1= yes, inferred2= yes, mainconnective= =Z, relation= =U, subformula1= =V, subformula2= =W, thing= proposition), '?retrieval': {'state': 'free'}}
# ==>
# {'=g': goal(state= store_in_list), '+imaginal': storelist(derived= , element= =Y, form10= , form11= , form12= , form13= , form14= , form15= , form2= , form3= , form4= , form5= , form6= , form7= , form8= , form9= , form= =X, inferred1= , inferred2= , mainconnective= =Z, relation= =U, subformula1= =V, subformula2= =W)}
# label first conjunct as inferred after second{'=g': goal(state= infer_first_conjunct_after_second), '?retrieval': {'state': 'error'}, '=imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= , inferred2= , mainconnective= conjunction, relation= , subformula1= =Y, subformula2= =Z, thing= proposition)}
# ==>
# {'=g': goal(state= retrieve_first_conjunct_after_second), '+imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= yes, inferred2= yes, mainconnective= conjunction, relation= , subformula1= =Y, subformula2= =Z, thing= proposition), '~retrieval': None}
# retrieve first conjunct after second{'=g': goal(state= retrieve_first_conjunct_after_second), '=imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= yes, inferred2= yes, mainconnective= conjunction, relation= , subformula1= =Y, subformula2= =Z, thing= proposition), '?retrieval': {'state': 'free'}}
# ==>
# {'=g': goal(state= label_first_conjunct_after_second), '+retrieval': proposition(derived= no, element= =U, form= =Y, inferred1= , inferred2= , mainconnective= , relation= , subformula1= , subformula2= , thing= proposition), '=imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= yes, inferred2= yes, mainconnective= conjunction, relation= , subformula1= =Y, subformula2= =Z, thing= proposition)}
# label first conjunct as derived after second{'=g': goal(state= label_first_conjunct_after_second), '?retrieval': {'state': 'free'}, '=retrieval': proposition(derived= , element= =U, form= =X, inferred1= , inferred2= , mainconnective= =V, relation= , subformula1= =Y, subformula2= =Z, thing= proposition), '?imaginal': {'state': 'free'}}
# ==>
# {'=g': goal(state= prepare_module3), '+imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= , inferred2= , mainconnective= =V, relation= , subformula1= =Y, subformula2= =Z, thing= proposition)}
# do we need to check for a clash? concept found{'=g': goal(state= module3), '=imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= , inferred2= , mainconnective= concept, relation= , subformula1= =Y, subformula2= , thing= proposition)}
# ==>
# {'=g': goal(state= find_clash), '+imaginal': checklist(element= =U, form2= , form3= , form4= , form5= , form6= , form7= , form8= , form= =X, mainconnective= concept, relation= , subformula1= =Y, subformula2= ), '~retrieval': None}
# do we need to check for a clash? negation found{'=g': goal(state= module3), '=imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= , inferred2= , mainconnective= negation, relation= , subformula1= =Y, subformula2= , thing= proposition)}
# ==>
# {'=g': goal(state= find_clash), '+imaginal': checklist(element= =U, form2= , form3= , form4= , form5= , form6= , form7= , form8= , form= =X, mainconnective= negation, relation= , subformula1= =Y, subformula2= ), '~retrieval': None}
# do we need to derive something new?{'=g': goal(state= module3), '=imaginal': proposition(derived= , element= =X, form= =Z, inferred1= , inferred2= , mainconnective= ~concept~negation, relation= , subformula1= =Y, subformula2= , thing= proposition)}
# ==>
# {'=g': goal(state= module2), '~imaginal': None, '~retrieval': None}
# retrieve the next proposition to store in the list{'=g': goal(state= store_in_list), '=imaginal': storelist(derived= , element= =Y, form10= =T9, form11= =T10, form12= =T11, form13= =T12, form14= =T13, form15= =T14, form2= =T1, form3= =T2, form4= =T3, form5= =T4, form6= =T5, form7= =T6, form8= =T7, form9= =T8, form= =X, inferred1= , inferred2= , mainconnective= =Z, relation= =U, subformula1= =V, subformula2= =W), '?retrieval': {'state': 'free'}}
# ==>
# {'=g': goal(state= store_in_list2), '+retrieval': proposition(derived= yes, element= , form= ~=X~=T11~=T5~=T7~=T4~=T12~=T3~=T9~=T1~=T2~=T8~=T13~=T14~=T6~=T10, inferred1= yes, inferred2= yes, mainconnective= , relation= , subformula1= , subformula2= , thing= proposition)}
# store the next proposition in the list{'=g': goal(state= store_in_list2), '=imaginal': storelist(derived= , element= =Y, form10= =T9, form11= =T10, form12= =T11, form13= =T12, form14= =T13, form15= , form2= =T1, form3= =T2, form4= =T3, form5= =T4, form6= =T5, form7= =T6, form8= =T7, form9= =T8, form= =X, inferred1= , inferred2= , mainconnective= =Z, relation= =U, subformula1= =V, subformula2= =W), '?retrieval': {'state': 'free'}, '=retrieval': proposition(derived= yes, element= =Y2, form= =X2, inferred1= yes, inferred2= yes, mainconnective= =Z2, relation= =U2, subformula1= =V2, subformula2= =W2, thing= proposition)}
# ==>
# {'=g': goal(state= store_in_list), '+imaginal': storelist(derived= yes, element= =Y2, form10= =T8, form11= =T9, form12= =T11, form13= =T11, form14= =T12, form15= =T13, form2= =X, form3= =T1, form4= =T2, form5= =T3, form6= =T4, form7= =T5, form8= =T6, form9= =T7, form= =X2, inferred1= yes, inferred2= yes, mainconnective= =Z2, relation= =U2, subformula1= =V2, subformula2= =W2)}
# use the list to select the next formula{'=g': goal(state= store_in_list2), '=imaginal': storelist(derived= , element= =Y, form10= =T9, form11= =T10, form12= =T11, form13= =T12, form14= =T13, form15= , form2= =T1, form3= =T2, form4= =T3, form5= =T4, form6= =T5, form7= =T6, form8= =T7, form9= =T8, form= =X, inferred1= , inferred2= , mainconnective= =Z, relation= =U, subformula1= =V, subformula2= =W), '?retrieval': {'state': 'error'}}
# ==>
# {'=g': goal(state= find_rule), '+retrieval': proposition(derived= yes, element= , form= ~=X~=T11~=T5~=T7~=T4~=T12~=T3~=T9~=T1~=T2~=T8~=T13~=T6~=T10, inferred1= , inferred2= , mainconnective= conjunction, relation= , subformula1= , subformula2= , thing= proposition)}
# confirm consistency{'=g': goal(state= find_rule), '?retrieval': {'state': 'error'}}
# ==>
# {'=g': goal(state= stop), '+manual': _manual(cmd= press_key, key= N)}
# skip and derive first formula and find formula to apply rule to{'=g': goal(state= store), '=imaginal': checklist(element= , form2= , form3= , form4= , form5= , form6= , form7= , form8= , form= , mainconnective= , relation= , subformula1= , subformula2= ), '?retrieval': {'state': 'error'}}
# ==>
# {'=g': goal(state= find_rule), '+retrieval': proposition(derived= yes, element= , form= , inferred1= , inferred2= , mainconnective= conjunction, relation= , subformula1= , subformula2= , thing= proposition)}
# find formula to apply rule to and conjunction found, first conjunct inferred? 1{'=g': goal(state= module2), '?retrieval': {'state': 'free'}}
# ==>
# {'=g': goal(state= first_conjunct_inferred1), '+imaginal': proposition(derived= yes, element= godel, form= godel:(austrian&logician)&(Einsteinsfriend&incomplete), inferred1= no, inferred2= no, mainconnective= conjunction, relation= , subformula1= godel:austrian&logician, subformula2= godel:Einsteinsfriend&incomplete, thing= proposition), '~retrieval': None}
# conjunction found, first conjunct inferred? 1 and conjunction found, first conjunct inferred? 2{'=g': goal(state= find_rule), '?retrieval': {'state': 'free'}, '=retrieval': proposition(derived= yes, element= =U, form= =X, inferred1= , inferred2= , mainconnective= conjunction, relation= , subformula1= =Y, subformula2= =Z, thing= proposition), '=imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= no, inferred2= no, mainconnective= conjunction, relation= , subformula1= =Y, subformula2= =Z, thing= proposition)}
# ==>
# {'=g': goal(state= first_conjunct_inferred2), '+retrieval': proposition(derived= , element= , form= =X, inferred1= yes, inferred2= , mainconnective= conjunction, relation= , subformula1= , subformula2= , thing= proposition), '=imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= no, inferred2= no, mainconnective= conjunction, relation= , subformula1= =Y, subformula2= =Z, thing= proposition)}
# label first conjunct as inferred and retrieve first conjunct{'=g': goal(state= first_conjunct_inferred2), '?retrieval': {'state': 'error'}, '=imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= yes, inferred2= , mainconnective= conjunction, relation= , subformula1= =Y, subformula2= =Z, thing= proposition)}
# ==>
# {'=g': goal(state= label_first_conjunct), '+retrieval': proposition(derived= , element= , form= =Y, inferred1= , inferred2= , mainconnective= , relation= , subformula1= , subformula2= , thing= proposition), '+imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= yes, inferred2= , mainconnective= conjunction, relation= , subformula1= =Y, subformula2= =Z, thing= proposition)}
# label first conjunct as derived and proceed to module 3{'=g': goal(state= label_first_conjunct), '=retrieval': proposition(derived= , element= =U, form= =X, inferred1= , inferred2= , mainconnective= =V, relation= , subformula1= =Y, subformula2= =Z, thing= proposition), '?imaginal': {'state': 'free'}, '=imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= , inferred2= , mainconnective= =V, relation= , subformula1= =Y, subformula2= =Z, thing= proposition)}
# ==>
# {'=g': goal(state= module3), '+imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= , inferred2= , mainconnective= =V, relation= , subformula1= =Y, subformula2= =Z, thing= proposition)}
# proceed to module 3 and do we need to derive something new?{'=g': goal(state= prepare_module3), '=imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= , inferred2= , mainconnective= =V, relation= , subformula1= =Y, subformula2= =Z, thing= proposition)}
# ==>
# {'=g': goal(state= module2), '~imaginal': None, '~retrieval': None}
# do we need to derive something new? and find formula to apply rule to{'=g': goal(state= module3), '=imaginal': proposition(derived= , element= =X, form= =Z, inferred1= , inferred2= , mainconnective= ~concept~negation, relation= , subformula1= =Y, subformula2= , thing= proposition)}
# ==>
# {'=g': goal(state= find_rule), '+retrieval': proposition(derived= yes, element= , form= , inferred1= , inferred2= , mainconnective= conjunction, relation= , subformula1= , subformula2= , thing= proposition), '~imaginal': None}
# find formula to apply rule to and conjunction found, second conjunct inferred? 1{'=g': goal(state= module2), '?retrieval': {'state': 'free'}}
# ==>
# {'=g': goal(state= second_conjunct_inferred1), '~retrieval': None, '+imaginal': proposition(derived= yes, element= godel, form= godel:(austrian&logician)&(Einsteinsfriend&incomplete), inferred1= no, inferred2= no, mainconnective= conjunction, relation= , subformula1= godel:austrian&logician, subformula2= godel:Einsteinsfriend&incomplete, thing= proposition)}
# conjunction found, second conjunct inferred? 1 and conjunction found, second conjunct inferred? 2{'=g': goal(state= find_rule), '?retrieval': {'state': 'free'}, '=retrieval': proposition(derived= yes, element= =U, form= =X, inferred1= , inferred2= , mainconnective= conjunction, relation= , subformula1= =Y, subformula2= =Z, thing= proposition), '=imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= no, inferred2= no, mainconnective= conjunction, relation= , subformula1= =Y, subformula2= =Z, thing= proposition)}
# ==>
# {'=g': goal(state= second_conjunct_inferred2), '+retrieval': proposition(derived= , element= , form= =X, inferred1= , inferred2= yes, mainconnective= conjunction, relation= , subformula1= , subformula2= , thing= proposition), '=imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= no, inferred2= no, mainconnective= conjunction, relation= , subformula1= =Y, subformula2= =Z, thing= proposition)}
# label second conjunct as inferred and retrieve second conjunct{'=g': goal(state= second_conjunct_inferred2), '?retrieval': {'state': 'error'}, '=imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= , inferred2= yes, mainconnective= conjunction, relation= , subformula1= =Y, subformula2= =Z, thing= proposition)}
# ==>
# {'=g': goal(state= label_second_conjunct), '+retrieval': proposition(derived= , element= , form= =Z, inferred1= , inferred2= , mainconnective= , relation= , subformula1= , subformula2= , thing= proposition), '+imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= , inferred2= yes, mainconnective= conjunction, relation= , subformula1= =Y, subformula2= =Z, thing= proposition)}
# label second conjunct as derived and proceed to module 3{'=g': goal(state= label_second_conjunct), '=retrieval': proposition(derived= , element= =U, form= =X, inferred1= , inferred2= , mainconnective= =V, relation= , subformula1= =Y, subformula2= =Z, thing= proposition), '?imaginal': {'state': 'free'}, '=imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= , inferred2= , mainconnective= =V, relation= , subformula1= =Y, subformula2= =Z, thing= proposition)}
# ==>
# {'=g': goal(state= module3), '+imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= , inferred2= , mainconnective= =V, relation= , subformula1= =Y, subformula2= =Z, thing= proposition)}
# do we need to derive something new? and find formula to apply rule to and conjunction found, first conjunct inferred? 1{'=g': goal(state= module3), '=imaginal': proposition(derived= , element= =X, form= =Z, inferred1= , inferred2= , mainconnective= ~concept~negation, relation= , subformula1= =Y, subformula2= , thing= proposition)}
# ==>
# {'=g': goal(state= first_conjunct_inferred1), '+imaginal': proposition(derived= yes, element= godel, form= godel:(austrian&logician)&(Einsteinsfriend&incomplete), inferred1= no, inferred2= no, mainconnective= conjunction, relation= , subformula1= godel:austrian&logician, subformula2= godel:Einsteinsfriend&incomplete, thing= proposition), '~retrieval': None}
# find formula to apply rule to and conjunction found, first conjunct inferred? 1 and conjunction found, first conjunct inferred? 2{'=g': goal(state= module2), '?retrieval': {'state': 'free'}, '=imaginal': proposition(derived= yes, element= godel, form= godel:(austrian&logician)&(Einsteinsfriend&incomplete), inferred1= no, inferred2= no, mainconnective= conjunction, relation= , subformula1= godel:austrian&logician, subformula2= godel:Einsteinsfriend&incomplete, thing= proposition)}
# ==>
# {'=g': goal(state= first_conjunct_inferred2), '+retrieval': proposition(derived= , element= , form= godel:(austrian&logician)&(Einsteinsfriend&incomplete), inferred1= yes, inferred2= , mainconnective= conjunction, relation= , subformula1= , subformula2= , thing= proposition), '=imaginal': proposition(derived= yes, element= godel, form= godel:(austrian&logician)&(Einsteinsfriend&incomplete), inferred1= no, inferred2= no, mainconnective= conjunction, relation= , subformula1= godel:austrian&logician, subformula2= godel:Einsteinsfriend&incomplete, thing= proposition)}
# conjunction found, first conjunct inferred? 2 and second_conjunct_inferred_a{'=g': goal(state= first_conjunct_inferred1), '=imaginal': proposition(derived= yes, element= =U, form= godel:(austrian&logician)&(Einsteinsfriend&incomplete), inferred1= no, inferred2= no, mainconnective= conjunction, relation= , subformula1= =Y, subformula2= =Z, thing= proposition), '?retrieval': {'state': 'free'}, '?imaginal': {'state': 'free'}}
# ==>
# {'=g': goal(state= pre_infer_second_conjunct_after_first), '+imaginal': proposition(derived= yes, element= godel, form= godel:(austrian&logician)&(Einsteinsfriend&incomplete), inferred1= yes, inferred2= =W__rule__second_conjunct_inferred_a, mainconnective= conjunction, relation= =Z__rule__second_conjunct_inferred_a, subformula1= godel:austrian&logician, subformula2= godel:Einsteinsfriend&incomplete, thing= proposition), '~retrieval': None}
# second_conjunct_inferred_a and second_conjunct_inferred_b{'=g': goal(state= first_conjunct_inferred2), '?retrieval': {'buffer': 'full'}, '=retrieval': proposition(derived= =S, element= =Y, form= =X, inferred1= yes, inferred2= =W, mainconnective= conjunction, relation= =Z, subformula1= =U, subformula2= =V, thing= proposition), '?imaginal': {'state': 'free'}, '=imaginal': proposition(derived= =S, element= =Y, form= =X, inferred1= yes, inferred2= =W, mainconnective= conjunction, relation= =Z, subformula1= =U, subformula2= =V, thing= proposition)}
# ==>
# {'=g': goal(state= infer_second_conjunct_after_first), '+retrieval': proposition(derived= =S, element= =Y, form= =X, inferred1= yes, inferred2= yes, mainconnective= conjunction, relation= =Z, subformula1= =U, subformula2= =V, thing= proposition), '=imaginal': proposition(derived= =S, element= =Y, form= =X, inferred1= yes, inferred2= =W, mainconnective= conjunction, relation= =Z, subformula1= =U, subformula2= =V, thing= proposition)}
# label second conjunct as inferred after first and retrieve second conjunct after first{'=g': goal(state= infer_second_conjunct_after_first), '?retrieval': {'state': 'error'}, '=imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= yes, inferred2= yes, mainconnective= conjunction, relation= , subformula1= =Y, subformula2= =Z, thing= proposition)}
# ==>
# {'=g': goal(state= label_second_conjunct_after_first), '+retrieval': proposition(derived= , element= , form= =Z, inferred1= , inferred2= , mainconnective= , relation= , subformula1= , subformula2= , thing= proposition), '+imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= yes, inferred2= yes, mainconnective= conjunction, relation= , subformula1= =Y, subformula2= =Z, thing= proposition)}
# label second conjunct as derived after first and proceed to module 3 and do we need to derive something new?{'=g': goal(state= label_second_conjunct_after_first), '?retrieval': {'state': 'free'}, '=retrieval': proposition(derived= , element= =U, form= =X, inferred1= , inferred2= , mainconnective= =V, relation= , subformula1= =Y, subformula2= =Z, thing= proposition), '?imaginal': {'state': 'free'}, '=imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= , inferred2= , mainconnective= =V, relation= , subformula1= =Y, subformula2= =Z, thing= proposition)}
# ==>
# {'=g': goal(state= module2), '~imaginal': None, '~retrieval': None}
# proceed to module 3 and do we need to derive something new? and find formula to apply rule to{'=g': goal(state= prepare_module3), '=imaginal': proposition(derived= yes, element= =U, form= =X, inferred1= , inferred2= , mainconnective= =V, relation= , subformula1= =Y, subformula2= =Z, thing= proposition)}
# ==>
# {'=g': goal(state= find_rule), '+retrieval': proposition(derived= yes, element= , form= , inferred1= , inferred2= , mainconnective= conjunction, relation= , subformula1= , subformula2= , thing= proposition), '~imaginal': None}

# %%
aBoxCon.MODEL_PARAMETERS
# Out:
# {'subsymbolic': False,
#  'rule_firing': 0.05,
#  'latency_factor': 0.1,
#  'latency_exponent': 1.0,
#  'decay': 0.5,
#  'baselevel_learning': True,
#  'optimized_learning': False,
#  'instantaneous_noise': 0,
#  'retrieval_threshold': 0,
#  'buffer_spreading_activation': {},
#  'spreading_activation_restricted': False,
#  'strength_of_association': 0,
#  'association_only_from_chunks': True,
#  'partial_matching': False,
#  'mismatch_penalty': 1,
#  'activation_trace': False,
#  'utility_noise': 0,
#  'utility_learning': False,
#  'utility_alpha': 0.2,
#  'motor_prepared': False,
#  'strict_harvesting': False,
#  'production_compilation': False,
#  'automatic_visual_search': True,
#  'emma': True,
#  'emma_noise': True,
#  'emma_landing_site_noise': False,
#  'eye_mvt_angle_parameter': 1,
#  'eye_mvt_scaling_parameter': 0.01}
